# %% [markdown]
# <a href="https://colab.research.google.com/github/RachelNderitu/Big-Data-Analytics/blob/main/Retail_PySpark.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Installation and Setup

# %%
# Install PySpark and Java
# Install Java
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null

# Download and extract Spark
# !wget -q https://archive.apache.org/dist/spark/spark-3.5.1/spark-3.5.1-bin-hadoop3.tgz
# !tar -xzf spark-3.5.1-bin-hadoop3.tgz

# Install PySpark
# !pip install -q pyspark

# Set environment variables
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.5.1-bin-hadoop3"

# Initialize SparkSession
from pyspark.sql import SparkSession
spark = SparkSession.builder \
    .appName("ColabSpark") \
    .master("local[*]") \
    .getOrCreate()

spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://af1701853c9a:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>ColabSpark</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# # 2. Data Extraction and Loading

# %%
import zipfile
import pandas as pd

# Extract the ZIP file
zip_path = "//content/online+retail.zip"
extract_path = "/content/"

try:
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)
    print("Extraction complete. Files extracted:")
    # !ls /content/
except FileNotFoundError:
    print("Zip file not found. Please ensure 'online retail.zip' is uploaded.")

# Load data into DataFrame
try:
    df = pd.read_excel('/content/Online Retail.xlsx', engine='openpyxl')  # 'openpyxl' is needed for .xlsx files
    print(" File loaded successfully!")
    print(f"Shape: {df.shape} (rows, columns)")
    print("\nFirst 5 rows:")
    display(df.head())
except Exception as e:
    print(f" Error: {e}")
# Out:
# Extraction complete. Files extracted:
# 'Online Retail.xlsx'   rdd_output    spark-3.5.1-bin-hadoop3
#  online+retail.zip     sample_data   spark-3.5.1-bin-hadoop3.tgz
#  File loaded successfully!
# Shape: (541909, 8) (rows, columns)
#
# First 5 rows:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %% [markdown]
# # 3. Create Spark RDD

# %%
# Convert Pandas DataFrame to Spark DataFrame
spark_df = spark.createDataFrame(df)

# Convert Spark DataFrame to RDD
rdd = spark_df.rdd

# Check RDD contents
print(" RDD created successfully!")
print(f"Number of partitions: {rdd.getNumPartitions()}")
print(f"First row: {rdd.first()}")
# Out:
#  RDD created successfully!
# Number of partitions: 2
# First row: Row(InvoiceNo='536365', StockCode='85123A', Description='WHITE HANGING HEART T-LIGHT HOLDER', Quantity=6, InvoiceDate=datetime.datetime(2010, 12, 1, 8, 26), UnitPrice=2.55, CustomerID=17850.0, Country='United Kingdom')

# %% [markdown]
# ## The RDD Descriptive Statistics

# %%
record_count = rdd.count()
print(f"Total number of records: {record_count}")

unique_items = rdd.map(lambda row: row["Description"]).distinct()
print("\nFirst 10 unique items:")
for item in unique_items.take(10):
    print(item)
# Out:
# Total number of records: 541909
#
# First 10 unique items:
# WHITE HANGING HEART T-LIGHT HOLDER
# WHITE METAL LANTERN
# RED WOOLLY HOTTIE WHITE HEART.
# GLASS STAR FROSTED T-LIGHT HOLDER
# HAND WARMER RED POLKA DOT
# POPPY'S PLAYHOUSE KITCHEN
# FELTCRAFT PRINCESS CHARLOTTE DOLL
# LOVE BUILDING BLOCK WORD
# RECIPE BOX WITH METAL HEART
# RED COAT RACK PARIS FASHION

# %% [markdown]
# ## 4. Low-level: Transformations

# %%
# map(): Transform to (Description, Quantity) pairs
map_example = rdd.map(lambda row: (row["Description"], row["Quantity"]))
print("map() - First 5 results:")
for result in map_example.take(5):
    print(result)
# Out:
# map() - First 5 results:
# ('WHITE HANGING HEART T-LIGHT HOLDER', 6)
# ('WHITE METAL LANTERN', 6)
# ('CREAM CUPID HEARTS COAT HANGER', 8)
# ('KNITTED UNION FLAG HOT WATER BOTTLE', 6)
# ('RED WOOLLY HOTTIE WHITE HEART.', 6)

# %%
# reduceByKey(): Count items per invoice
invoice_counts = rdd.map(lambda row: (row["InvoiceNo"], 1))\
                   .reduceByKey(lambda a, b: a + b)\
                   .sortByKey()
print("\nItems per Invoice (first 5):")
for invoice, count in invoice_counts.take(5):
    print(f"Invoice {invoice}: {count} items")
# Out:
# Items per Invoice (first 5):
# Invoice 536365: 7 items
# Invoice 536366: 2 items
# Invoice 536367: 12 items
# Invoice 536368: 4 items
# Invoice 536369: 1 items

# %%
# FlatMap(): Split description words
# Each word in the Description field becomes a separate record in the new words_rdd.
words_rdd = rdd.flatMap(lambda row: row.Description.split() if row.Description else [])
print(words_rdd.take(10))
# Out:
# ['WHITE', 'HANGING', 'HEART', 'T-LIGHT', 'HOLDER', 'WHITE', 'METAL', 'LANTERN', 'CREAM', 'CUPID']

# %%
# Distinct(): Removes any duplicate words
unique_words_rdd = words_rdd.distinct()
unique_words = unique_words_rdd.take(10)  # Take first 10 unique words
print(unique_words)
# Out:
# ['HOLDER', 'CUPID', 'HANGER', 'FLAG', 'HOT', 'WATER', 'WOOLLY', 'SET', '7', 'BABUSHKA']

# %%
unique_countries = rdd.map(lambda row: row.Country).distinct()
print(unique_countries.take(10))
# Out:
# ['France', 'Australia', 'Germany', 'EIRE', 'Italy', 'Lithuania', 'Japan', 'Iceland', 'Channel Islands', 'Cyprus']

# %%
# Filter(): Filters elements based on a condition.
# Filter expensive items (UnitPrice > 10)
expensive_items_10 = rdd.filter(lambda row: row["UnitPrice"] > 10)\
                       .map(lambda row: (row["Description"], row["UnitPrice"]))
print("Items with UnitPrice > 10 (first 5):")
for desc, price in expensive_items_10.take(5):
    print(f"{desc}: ${price}")
# Out:
# Items with UnitPrice > 10 (first 5):
# POSTAGE: $18.0
# VICTORIAN SEWING BOX LARGE: $10.95
# Discount: $27.5
# 3 TIER CAKE TIN GREEN AND CREAM: $14.95
# 3 TIER CAKE TIN RED AND CREAM: $14.95

# %%
# Filter very expensive items (UnitPrice > 5000)
expensive_items_5000 = rdd.filter(lambda row: row["UnitPrice"] > 5000)\
                         .map(lambda row: (row["Description"], row["UnitPrice"]))
print("\nItems with UnitPrice > 5000:")
for desc, price in expensive_items_5000.collect():
    print(f"{desc}: ${price}")
# Out:
# Items with UnitPrice > 5000:
# AMAZON FEE: $13541.33
# AMAZON FEE: $13541.33
# AMAZON FEE: $13474.79
# AMAZON FEE: $5519.25
# AMAZON FEE: $13541.33
# AMAZON FEE: $6706.71
# AMAZON FEE: $16888.02
# AMAZON FEE: $16453.71
# AMAZON FEE: $5575.28
# AMAZON FEE: $5258.77
# AMAZON FEE: $5693.05
# AMAZON FEE: $5225.03
# POSTAGE: $8142.75
# POSTAGE: $8142.75
# Manual: $6930.0
# AMAZON FEE: $5876.4
# AMAZON FEE: $7006.83
# Manual: $38970.0
# AMAZON FEE: $5791.18
# AMAZON FEE: $6497.47
# AMAZON FEE: $6721.37
# Adjust bad debt: $11062.06
# AMAZON FEE: $6662.51
# AMAZON FEE: $5522.14
# AMAZON FEE: $7427.97
# AMAZON FEE: $5942.57
# AMAZON FEE: $5942.57
# AMAZON FEE: $5877.18
# AMAZON FEE: $8286.22
# AMAZON FEE: $11586.5
# AMAZON FEE: $17836.46

# %% [markdown]
# ##  Low-level: Actions

# %%
# takeOrdered(): Returns the top n elements sorted by the key
# takeOrdered(): Top 5 highest quantity items
top_quantities = rdd.takeOrdered(5, key=lambda row: -row["Quantity"])
print("Top 5 highest quantity items:")
for result in top_quantities:
    print(f"Description: {result['Description']}, Quantity: {result['Quantity']}")
# Out:
# Top 5 highest quantity items:
# Description: PAPER CRAFT , LITTLE BIRDIE, Quantity: 80995
# Description: MEDIUM CERAMIC TOP STORAGE JAR, Quantity: 74215
# Description: ASSTD DESIGN 3D PAPER STICKERS, Quantity: 12540
# Description: NaN, Quantity: 5568
# Description: WORLD WAR 2 GLIDERS ASSTD DESIGNS, Quantity: 4800

# %%
# count(): Count the number of elements in the RDD
# Count the total number of elements in the RDD
total_count = rdd.count()
print(f"Total number of records: {total_count}")
# Out:
# Total number of records: 541909

# %%
# collect(): Return all elements as a list to the driver
# Collect all elements in the RDD and print them
all_records = rdd.collect()
print(f"Total records collected: {len(all_records)}")
for record in all_records[:5]:  # Show the first 5 records
    print(record)
# Out:
# Total records collected: 541909
# Row(InvoiceNo='536365', StockCode='85123A', Description='WHITE HANGING HEART T-LIGHT HOLDER', Quantity=6, InvoiceDate=datetime.datetime(2010, 12, 1, 8, 26), UnitPrice=2.55, CustomerID=17850.0, Country='United Kingdom')
# Row(InvoiceNo='536365', StockCode='71053', Description='WHITE METAL LANTERN', Quantity=6, InvoiceDate=datetime.datetime(2010, 12, 1, 8, 26), UnitPrice=3.39, CustomerID=17850.0, Country='United Kingdom')
# Row(InvoiceNo='536365', StockCode='84406B', Description='CREAM CUPID HEARTS COAT HANGER', Quantity=8, InvoiceDate=datetime.datetime(2010, 12, 1, 8, 26), UnitPrice=2.75, CustomerID=17850.0, Country='United Kingdom')
# Row(InvoiceNo='536365', StockCode='84029G', Description='KNITTED UNION FLAG HOT WATER BOTTLE', Quantity=6, InvoiceDate=datetime.datetime(2010, 12, 1, 8, 26), UnitPrice=3.39, CustomerID=17850.0, Country='United Kingdom')
# Row(InvoiceNo='536365', StockCode='84029E', Description='RED WOOLLY HOTTIE WHITE HEART.', Quantity=6, InvoiceDate=datetime.datetime(2010, 12, 1, 8, 26), UnitPrice=3.39, CustomerID=17850.0, Country='United Kingdom')

# %%
# first(): Return the first element of the RDD
# Get the first record in the RDD
first_record = rdd.first()
print("First record in RDD:")
print(first_record)
# Out:
# First record in RDD:
# Row(InvoiceNo='536365', StockCode='85123A', Description='WHITE HANGING HEART T-LIGHT HOLDER', Quantity=6, InvoiceDate=datetime.datetime(2010, 12, 1, 8, 26), UnitPrice=2.55, CustomerID=17850.0, Country='United Kingdom')

# %%
# saveAsTextFile(path): Save the RDD to a text file on disk
# Save the RDD as a text file in the specified path
rdd.saveAsTextFile("/content/rdd_output")

# %%
# reduce(func): Aggregate the elements of the RDD using the specified associative function. It takes a binary function and combines elements in the RDD. It’s commonly used for aggregation tasks like summing values.
# Reduce to calculate the total quantity of all items in the RDD
total_quantity = rdd.map(lambda row: row["Quantity"]).reduce(lambda a, b: a + b)
print(f"Total quantity of all items: {total_quantity}")
# Out:
# Total quantity of all items: 5176450

# %%
# countByKey(): Count the occurrences of each key in an RDD of key-value pairs (only works on RDDs with key-value pairs)
# Assuming we have an RDD of key-value pairs, like (item, quantity)
rdd_kv = rdd.map(lambda row: (row["Description"], row["Quantity"]))

# Count occurrences of each description
item_count = rdd_kv.countByKey()
print("Item counts:")
for item, count in item_count.items():
    print(f"Description: {item}, Count: {count}")
# Out:
# Item counts:
# Description: WHITE HANGING HEART T-LIGHT HOLDER, Count: 2369
# Description: WHITE METAL LANTERN, Count: 328
# Description: CREAM CUPID HEARTS COAT HANGER, Count: 293
# Description: KNITTED UNION FLAG HOT WATER BOTTLE, Count: 473
# Description: RED WOOLLY HOTTIE WHITE HEART., Count: 449
# Description: SET 7 BABUSHKA NESTING BOXES, Count: 389
# Description: GLASS STAR FROSTED T-LIGHT HOLDER, Count: 141
# Description: HAND WARMER UNION JACK, Count: 515
# Description: HAND WARMER RED POLKA DOT, Count: 18
# Description: ASSORTED COLOUR BIRD ORNAMENT, Count: 1501
# Description: POPPY'S PLAYHOUSE BEDROOM , Count: 436
# Description: POPPY'S PLAYHOUSE KITCHEN, Count: 451
# Description: FELTCRAFT PRINCESS CHARLOTTE DOLL, Count: 469
# Description: IVORY KNITTED MUG COSY , Count: 111
# Description: BOX OF 6 ASSORTED COLOUR TEASPOONS, Count: 213
# Description: BOX OF VINTAGE JIGSAW BLOCKS , Count: 243
# Description: BOX OF VINTAGE ALPHABET BLOCKS, Count: 272
# Description: HOME BUILDING BLOCK WORD, Count: 806
# Description: LOVE BUILDING BLOCK WORD, Count: 656
# Description: RECIPE BOX WITH METAL HEART, Count: 8
# Description: DOORMAT NEW ENGLAND, Count: 608
# Description: JAM MAKING SET WITH JARS, Count: 1229
# Description: RED COAT RACK PARIS FASHION, Count: 114
# Description: YELLOW COAT RACK PARIS FASHION, Count: 103
# Description: BLUE COAT RACK PARIS FASHION, Count: 160
# Description: BATH BUILDING BLOCK WORD, Count: 285
# Description: ALARM CLOCK BAKELIKE PINK, Count: 810
# Description: ALARM CLOCK BAKELIKE RED , Count: 1107
# Description: ALARM CLOCK BAKELIKE GREEN, Count: 1024
# Description: PANDA AND BUNNIES STICKER SHEET, Count: 81
# Description: STARS GIFT TAPE , Count: 134
# Description: INFLATABLE POLITICAL GLOBE , Count: 71
# Description: VINTAGE HEADS AND TAILS CARD GAME , Count: 617
# Description: SET/2 RED RETROSPOT TEA TOWELS , Count: 403
# Description: ROUND SNACK BOXES SET OF4 WOODLAND , Count: 764
# Description: SPACEBOY LUNCH BOX , Count: 924
# Description: LUNCH BOX I LOVE LONDON, Count: 750
# Description: CIRCUS PARADE LUNCH BOX , Count: 411
# Description: CHARLOTTE BAG DOLLY GIRL DESIGN, Count: 425
# Description: RED TOADSTOOL LED NIGHT LIGHT, Count: 874
# Description:  SET 2 TEA TOWELS I LOVE LONDON , Count: 282
# Description: VINTAGE SEASIDE JIGSAW PUZZLES, Count: 150
# Description: MINI JIGSAW CIRCUS PARADE , Count: 93
# Description: MINI JIGSAW SPACEBOY, Count: 180
# Description: MINI PAINT SET VINTAGE , Count: 390
# Description: POSTAGE, Count: 1252
# Description: PAPER CHAIN KIT 50'S CHRISTMAS , Count: 1210
# Description: EDWARDIAN PARASOL RED, Count: 330
# Description: RETRO COFFEE MUGS ASSORTED, Count: 171
# Description: SAVE THE PLANET MUG, Count: 374
# Description: VINTAGE BILLBOARD DRINK ME MUG, Count: 181
# Description: VINTAGE BILLBOARD LOVE/HATE MUG, Count: 202
# Description: WOOD 2 DRAWER CABINET WHITE FINISH, Count: 600
# Description: WOOD S/3 CABINET ANT WHITE FINISH, Count: 424
# Description: WOODEN PICTURE FRAME WHITE FINISH, Count: 1129
# Description: WOODEN FRAME ANTIQUE WHITE , Count: 999
# Description: VICTORIAN SEWING BOX LARGE, Count: 182
# Description: HOT WATER BOTTLE TEA AND SYMPATHY, Count: 656
# Description: RED HANGING HEART T-LIGHT HOLDER, Count: 773
# Description: JUMBO BAG PINK POLKADOT, Count: 1251
# Description: JUMBO  BAG BAROQUE BLACK WHITE, Count: 960
# Description: JUMBO BAG CHARLIE AND LOLA TOYS, Count: 302
# Description: STRAWBERRY CHARLOTTE BAG, Count: 742
# Description: RED 3 PIECE RETROSPOT CUTLERY SET, Count: 123
# Description: BLUE 3 PIECE POLKADOT CUTLERY SET, Count: 108
# Description: SET/6 RED SPOTTY PAPER PLATES, Count: 532
# Description: LUNCH BAG RED RETROSPOT, Count: 1638
# Description: STRAWBERRY LUNCH BOX WITH CUTLERY, Count: 598
# Description: LUNCH BOX WITH CUTLERY RETROSPOT , Count: 498
# Description: PACK OF 72 RETROSPOT CAKE CASES, Count: 1385
# Description: PACK OF 60 DINOSAUR CAKE CASES, Count: 641
# Description: PACK OF 60 PINK PAISLEY CAKE CASES, Count: 896
# Description: 60 TEATIME FAIRY CAKE CASES, Count: 871
# Description: TOMATO CHARLIE+LOLA COASTER SET, Count: 88
# Description: CHARLIE & LOLA WASTEPAPER BIN FLORA, Count: 119
# Description: RED CHARLIE+LOLA PERSONAL DOORSIGN, Count: 133
# Description: JUMBO STORAGE BAG SUKI, Count: 1214
# Description: JUMBO BAG PINK VINTAGE PAISLEY, Count: 885
# Description: JAM MAKING SET PRINTED, Count: 1182
# Description: RETROSPOT TEA SET CERAMIC 11 PC , Count: 988
# Description: GIRLY PINK TOOL SET, Count: 1
# Description: JUMBO SHOPPER VINTAGE RED PAISLEY, Count: 1202
# Description: AIRLINE LOUNGE,METAL SIGN, Count: 293
# Description: WHITE SPOT RED CERAMIC DRAWER KNOB, Count: 426
# Description: RED DRAWER KNOB ACRYLIC EDWARDIAN, Count: 146
# Description: CLEAR DRAWER KNOB ACRYLIC EDWARDIAN, Count: 458
# Description: PHOTO CLIP LINE, Count: 53
# Description: FELT EGG COSY CHICKEN, Count: 146
# Description: PIGGY BANK RETROSPOT , Count: 357
# Description: SKULL SHOULDER BAG, Count: 413
# Description: YOU'RE CONFUSING ME METAL SIGN , Count: 469
# Description: COOK WITH WINE METAL SIGN , Count: 745
# Description: GIN + TONIC DIET METAL SIGN, Count: 775
# Description: YELLOW BREAKFAST CUP AND SAUCER, Count: 20
# Description: PINK BREAKFAST CUP AND SAUCER , Count: 11
# Description: PAPER CHAIN KIT RETROSPOT, Count: 619
# Description: SMALL HEART FLOWERS HOOK , Count: 176
# Description: TEA TIME DES TEA COSY, Count: 114
# Description: FELT EGG COSY WHITE RABBIT , Count: 117
# Description: ZINC WILLIE WINKIE  CANDLE STICK, Count: 274
# Description: CERAMIC CHERRY CAKE MONEY BANK, Count: 283
# Description: RETROSPOT LARGE MILK JUG, Count: 361
# Description: SET OF 6 FUNKY BEAKERS, Count: 163
# Description: EDWARDIAN PARASOL BLACK, Count: 388
# Description: EDWARDIAN PARASOL NATURAL, Count: 551
# Description: CERAMIC STRAWBERRY CAKE MONEY BANK, Count: 406
# Description: BLUE OWL SOFT TOY, Count: 120
# Description: BALLOON ART MAKE YOUR OWN FLOWERS, Count: 104
# Description: GLASS CLOCHE SMALL, Count: 166
# Description: GUMBALL MONOCHROME COAT RACK, Count: 114
# Description: DOORMAT FANCY FONT HOME SWEET HOME, Count: 506
# Description: Discount, Count: 77
# Description: VINTAGE SNAKES & LADDERS, Count: 401
# Description: CHOCOLATE CALCULATOR, Count: 206
# Description: RECYCLING BAG RETROSPOT , Count: 760
# Description: TOY TIDY PINK POLKADOT, Count: 482
# Description: ANTIQUE GLASS DRESSING TABLE POT, Count: 285
# Description: IVORY GIANT GARDEN THERMOMETER, Count: 205
# Description: 3 TIER CAKE TIN GREEN AND CREAM, Count: 214
# Description: 3 TIER CAKE TIN RED AND CREAM, Count: 182
# Description: SET 3 WICKER OVAL BASKETS W LIDS, Count: 33
# Description: SET OF 3 COLOURED  FLYING DUCKS, Count: 47
# Description: WOOD BLACK BOARD ANT WHITE FINISH, Count: 698
# Description: COLOUR GLASS T-LIGHT HOLDER HANGING, Count: 640
# Description: HANGING METAL HEART LANTERN, Count: 371
# Description: HANGING MEDINA LANTERN SMALL, Count: 28
# Description: NATURAL SLATE HEART CHALKBOARD , Count: 1280
# Description: HEART OF WICKER SMALL, Count: 1237
# Description: HEART OF WICKER LARGE, Count: 961
# Description: WHITE LOVEBIRD LANTERN, Count: 168
# Description: CLASSIC METAL BIRDCAGE PLANT HOLDER, Count: 301
# Description: CREAM HEART CARD HOLDER, Count: 536
# Description: ENAMEL FLOWER JUG CREAM, Count: 528
# Description: ENAMEL FIRE BUCKET CREAM, Count: 118
# Description: ENAMEL BREAD BIN CREAM, Count: 473
# Description: JUMBO BAG DOLLY GIRL DESIGN, Count: 454
# Description: TRADITIONAL CHRISTMAS RIBBONS, Count: 368
# Description: ORGANISER WOOD ANTIQUE WHITE , Count: 86
# Description: LUNCH BAG DOLLY GIRL DESIGN, Count: 706
# Description: WHITE WIRE EGG HOLDER, Count: 81
# Description: JUMBO BAG RED RETROSPOT, Count: 2159
# Description: CHILLI LIGHTS, Count: 679
# Description: LIGHT GARLAND BUTTERFILES PINK, Count: 142
# Description: WOODEN OWLS LIGHT GARLAND , Count: 160
# Description: FAIRY TALE COTTAGE NIGHTLIGHT, Count: 97
# Description: HOME SMALL WOOD LETTERS, Count: 136
# Description: GINGHAM HEART  DOORSTOP RED, Count: 247
# Description: FIVE HEART HANGING DECORATION, Count: 145
# Description: ASSORTED BOTTLE TOP  MAGNETS , Count: 189
# Description: FRIDGE MAGNETS US DINER ASSORTED, Count: 107
# Description: HOMEMADE JAM SCENTED CANDLES, Count: 655
# Description: FRIDGE MAGNETS LES ENFANTS ASSORTED, Count: 88
# Description: ROSE CARAVAN DOORSTOP, Count: 166
# Description: 5 HOOK HANGER MAGIC TOADSTOOL, Count: 37
# Description: CHRISTMAS LIGHTS 10 REINDEER, Count: 333
# Description: VINTAGE UNION JACK CUSHION COVER, Count: 112
# Description: SET OF 3 GOLD FLYING DUCKS, Count: 22
# Description: RED RETROSPOT UMBRELLA, Count: 378
# Description: BLACK/BLUE POLKADOT UMBRELLA, Count: 294
# Description: RED DINER WALL CLOCK, Count: 472
# Description: BLUE DINER WALL CLOCK, Count: 372
# Description: IVORY DINER WALL CLOCK, Count: 441
# Description: LARGE HEART MEASURING SPOONS, Count: 382
# Description: SMALL HEART MEASURING SPOONS, Count: 489
# Description: JAM JAR WITH PINK LID, Count: 366
# Description: JAM JAR WITH GREEN LID, Count: 321
# Description: ROSE COTTAGE KEEPSAKE BOX , Count: 200
# Description: HANGING HEART ZINC T-LIGHT HOLDER, Count: 612
# Description: PAPER CHAIN KIT VINTAGE CHRISTMAS, Count: 850
# Description: DISCO BALL CHRISTMAS DECORATION, Count: 222
# Description: SMALL POPCORN HOLDER, Count: 611
# Description: LARGE POPCORN HOLDER , Count: 101
# Description: SET/20 RED RETROSPOT PAPER NAPKINS , Count: 1015
# Description: SET/6 RED SPOTTY PAPER CUPS, Count: 439
# Description: POLKADOT RAIN HAT , Count: 236
# Description: DELUXE SEWING KIT , Count: 345
# Description: RETROSPOT HEART HOT WATER BOTTLE, Count: 655
# Description: ENGLISH ROSE HOT WATER BOTTLE, Count: 390
# Description: PHOTO CUBE, Count: 331
# Description: PLASTERS IN TIN CIRCUS PARADE , Count: 591
# Description: PACK OF 12 PINK PAISLEY TISSUES , Count: 219
# Description: PACK OF 12 BLUE PAISLEY TISSUES , Count: 156
# Description: PACK OF 12 RED RETROSPOT TISSUES , Count: 303
# Description: CHICK GREY HOT WATER BOTTLE, Count: 422
# Description: PLASTERS IN TIN VINTAGE PAISLEY , Count: 589
# Description: PLASTERS IN TIN SKULLS, Count: 593
# Description: 3 STRIPEY MICE FELTCRAFT, Count: 483
# Description: SET OF 6 SOLDIER SKITTLES, Count: 455
# Description: TRADITIONAL WOODEN SKIPPING ROPE, Count: 451
# Description: WOODEN BOX OF DOMINOES, Count: 607
# Description: RUSTIC  SEVENTEEN DRAWER SIDEBOARD, Count: 29
# Description: PARTY CONES CARNIVAL ASSORTED, Count: 23
# Description: PARTY CONES CANDY ASSORTED, Count: 79
# Description: PICNIC BASKET WICKER SMALL, Count: 477
# Description: STAR DECORATION PAINTED ZINC , Count: 189
# Description: RETROSPOT LAMP, Count: 168
# Description: FANCY FONT BIRTHDAY CARD, , Count: 327
# Description: HAND WARMER SCOTTY DOG DESIGN, Count: 585
# Description: HAND WARMER OWL DESIGN, Count: 687
# Description: HAND WARMER RED RETROSPOT, Count: 395
# Description: DOG BOWL CHASING BALL DESIGN, Count: 135
# Description: CLOTHES PEGS RETROSPOT PACK 24 , Count: 792
# Description: HAND OVER THE CHOCOLATE   SIGN , Count: 686
# Description: TRAVEL SEWING KIT, Count: 478
# Description: BLACK HEART CARD HOLDER, Count: 191
# Description: SMALL GLASS HEART TRINKET POT, Count: 585
# Description: ALARM CLOCK BAKELIKE IVORY, Count: 594
# Description: ALARM CLOCK BAKELIKE ORANGE, Count: 473
# Description: HAND WARMER BIRD DESIGN, Count: 574
# Description: IVORY EMBROIDERED QUILT , Count: 31
# Description: SET OF 3 BLACK FLYING DUCKS, Count: 121
# Description: RED RETROSPOT MUG, Count: 169
# Description: BABUSHKA LIGHTS STRING OF 10, Count: 155
# Description: DOORMAT FAIRY CAKE, Count: 371
# Description: STRAWBERRY CERAMIC TRINKET BOX, Count: 770
# Description: PINK DOUGHNUT TRINKET POT , Count: 266
# Description: SILK PURSE BABUSHKA PINK, Count: 146
# Description: HOT WATER BOTTLE I AM SO POORLY, Count: 679
# Description: CHOCOLATE HOT WATER BOTTLE, Count: 889
# Description: WHITE SKULL HOT WATER BOTTLE , Count: 518
# Description: SCOTTIE DOG HOT WATER BOTTLE, Count: 798
# Description: BIRD HOUSE HOT WATER BOTTLE, Count: 290
# Description: BOUDOIR SQUARE TISSUE BOX, Count: 186
# Description: SKULLS SQUARE TISSUE BOX, Count: 61
# Description: PHOTO FRAME CORNICE, Count: 533
# Description: SILK PURSE BABUSHKA RED, Count: 52
# Description: PICTURE DOMINOES, Count: 363
# Description: S/6 SEW ON CROCHET FLOWERS, Count: 20
# Description: SCANDINAVIAN REDS RIBBONS, Count: 465
# Description: BALLOONS  WRITING SET , Count: 353
# Description: LAVENDER INCENSE IN TIN, Count: 26
# Description: TV DINNER TRAY VINTAGE PAISLEY, Count: 114
# Description: SET OF 4 ENGLISH ROSE PLACEMATS, Count: 301
# Description: SET OF 4 ENGLISH ROSE COASTERS, Count: 287
# Description: TRIPLE PHOTO FRAME CORNICE , Count: 235
# Description: FAMILY PHOTO FRAME CORNICE, Count: 287
# Description: MIRRORED DISCO BALL , Count: 144
# Description: DISCO BALL ROTATOR BATTERY OPERATED, Count: 109
# Description: SILVER LOOKING MIRROR, Count: 2
# Description: LADIES & GENTLEMEN METAL SIGN, Count: 485
# Description: METAL SIGN HER DINNER IS SERVED , Count: 95
# Description: DOORMAT TOPIARY, Count: 210
# Description: BATHROOM METAL SIGN, Count: 641
# Description: KITCHEN METAL SIGN, Count: 310
# Description: TOILET METAL SIGN, Count: 411
# Description: METAL SIGN TAKE IT OR LEAVE IT , Count: 422
# Description: I'M ON HOLIDAY METAL SIGN, Count: 372
# Description: GROW YOUR OWN BASIL IN ENAMEL MUG, Count: 228
# Description: SET/10 PINK POLKADOT PARTY CANDLES, Count: 358
# Description: SET 20 NAPKINS FAIRY CAKES DESIGN , Count: 363
# Description: SET OF 6 T-LIGHTS SNOWMEN, Count: 171
# Description: SET OF 6 T-LIGHTS SANTA, Count: 213
# Description: SET OF 9 HEART SHAPED BALLOONS, Count: 275
# Description: SANDWICH BATH SPONGE, Count: 97
# Description: APPLE BATH SPONGE, Count: 233
# Description: STRAWBERRY BATH SPONGE , Count: 232
# Description: BLACK PIRATE TREASURE CHEST, Count: 149
# Description: STAR PORTABLE TABLE LIGHT , Count: 52
# Description: SNOWFLAKE PORTABLE TABLE LIGHT , Count: 131
# Description: PINK OVAL JEWELLED MIRROR, Count: 11
# Description: RETROSPOT CIGAR BOX MATCHES , Count: 231
# Description: COSY HOUR GIANT TUBE MATCHES, Count: 30
# Description: JAZZ HEARTS PURSE NOTEBOOK, Count: 294
# Description: CANDLEHOLDER PINK HANGING HEART, Count: 416
# Description: ASSORTED COLOUR MINI CASES, Count: 394
# Description: LUNCH BAG SPACEBOY DESIGN , Count: 1192
# Description: LUNCH BAG WOODLAND, Count: 1061
# Description: LUNCH BAG PINK POLKADOT, Count: 1137
# Description: GUMBALL COAT RACK, Count: 728
# Description: BLUE NEW BAROQUE CANDLESTICK CANDLE, Count: 40
# Description: PINK NEW BAROQUECANDLESTICK CANDLE, Count: 44
# Description: FAIRY CAKE FLANNEL ASSORTED COLOUR, Count: 270
# Description: BREAD BIN DINER STYLE PINK, Count: 137
# Description: TEA TIME TABLE CLOTH, Count: 33
# Description: HOT WATER BOTTLE BABUSHKA , Count: 188
# Description: HEART IVORY TRELLIS SMALL, Count: 389
# Description: PINK DRAWER KNOB ACRYLIC EDWARDIAN, Count: 264
# Description: GREEN DRAWER KNOB ACRYLIC EDWARDIAN, Count: 196
# Description: BLUE DRAWER KNOB ACRYLIC EDWARDIAN, Count: 200
# Description: SET 6 FOOTBALL CELEBRATION CANDLES, Count: 109
# Description: SET OF 6 GIRLS CELEBRATION CANDLES, Count: 128
# Description: ROMANTIC PINKS RIBBONS , Count: 232
# Description: BRIGHT BLUES RIBBONS , Count: 113
# Description: CHOCOLATE BOX RIBBONS , Count: 328
# Description: PARTY INVITES FOOTBALL, Count: 83
# Description: PARTY INVITES JAZZ HEARTS, Count: 102
# Description: PARTY INVITES SPACEMAN, Count: 75
# Description: SET OF 3 BUTTERFLY COOKIE CUTTERS, Count: 707
# Description: SET OF 3 HEART COOKIE CUTTERS, Count: 700
# Description: 3 PIECE SPACEBOY COOKIE CUTTER SET, Count: 391
# Description: PACK OF 72 SKULL CAKE CASES, Count: 678
# Description: PACK OF 60 SPACEBOY CAKE CASES, Count: 535
# Description: 72 SWEETHEART FAIRY CAKE CASES, Count: 650
# Description: LUNCH BAG SUKI  DESIGN , Count: 209
# Description: LUNCH BAG CARS BLUE, Count: 1197
# Description: LUNCH BAG  BLACK SKULL., Count: 1350
# Description: HEART IVORY TRELLIS LARGE, Count: 333
# Description: SET/5 RED RETROSPOT LID GLASS BOWLS, Count: 936
# Description: MAGIC DRAWING SLATE DINOSAUR, Count: 175
# Description: MAGIC DRAWING SLATE BAKE A CAKE , Count: 90
# Description: 12 PENCILS TALL TUBE SKULLS, Count: 266
# Description: RED  HARMONICA IN BOX , Count: 676
# Description: BLUE HARMONICA IN BOX , Count: 615
# Description: SKULLS  WATER TRANSFER TATTOOS , Count: 176
# Description: PACK 3 BOXES BIRD PANNETONE , Count: 187
# Description: SET OF 20 KIDS COOKIE CUTTERS, Count: 533
# Description: 10 COLOUR SPACEBOY PEN, Count: 327
# Description: VICTORIAN GLASS HANGING T-LIGHT, Count: 1072
# Description: SINGLE HEART ZINC T-LIGHT HOLDER, Count: 510
# Description: HANGING METAL STAR LANTERN, Count: 209
# Description: SILVER HANGING T-LIGHT HOLDER, Count: 329
# Description: DOORMAT RED RETROSPOT, Count: 707
# Description: DOORMAT HEARTS, Count: 599
# Description: NATURAL SLATE RECTANGLE CHALKBOARD, Count: 427
# Description: LOVEBIRD HANGING DECORATION WHITE , Count: 560
# Description: PENS ASSORTED FUNNY FACE, Count: 218
# Description: CARD CIRCUS PARADE, Count: 289
# Description: WRAP COWBOYS  , Count: 72
# Description: AIRLINE BAG VINTAGE TOKYO 78, Count: 413
# Description: SET OF 72 RETROSPOT PAPER  DOILIES, Count: 462
# Description: SLEEPING CAT ERASERS, Count: 298
# Description: CARD BIRTHDAY COWBOY, Count: 226
# Description: PACK 3 BOXES CHRISTMAS PANNETONE, Count: 169
# Description: ROTATING SILVER ANGELS T-LIGHT HLDR, Count: 475
# Description: RIBBON REEL MAKING SNOWMEN , Count: 232
# Description: 4 TRADITIONAL SPINNING TOPS, Count: 498
# Description: BAG 500g SWIRLY MARBLES, Count: 146
# Description: 5 STRAND GLASS NECKLACE CRYSTAL, Count: 15
# Description: SQUARECUSHION COVER PINK UNION FLAG, Count: 32
# Description: SPACEBOY CHILDRENS EGG CUP, Count: 189
# Description: CHILDREN'S SPACEBOY MUG, Count: 239
# Description: FELTCRAFT CUSHION OWL, Count: 488
# Description: BLACK CANDELABRA T-LIGHT HOLDER, Count: 92
# Description: TOY TIDY DOLLY GIRL DESIGN, Count: 165
# Description: SET 12 LAVENDER  BOTANICAL T-LIGHTS, Count: 78
# Description: UNION JACK FLAG LUGGAGE TAG, Count: 197
# Description: RED HEART LUGGAGE TAG, Count: 101
# Description: RED GLASS TASSLE BAG CHARM, Count: 16
# Description: CLEAR ACRYLIC FACETED BANGLE, Count: 7
# Description: DOORMAT UNION JACK GUNS AND ROSES, Count: 210
# Description: VANILLA SCENT CANDLE JEWELLED BOX, Count: 113
# Description: FULL ENGLISH BREAKFAST PLATE, Count: 307
# Description: MAGIC DRAWING SLATE CIRCUS PARADE  , Count: 203
# Description: CHRISTMAS HANGING HEART WITH BELL, Count: 29
# Description: CAKE STAND VICTORIAN FILIGREE MED, Count: 131
# Description: PAISLEY PATTERN  STICKERS, Count: 32
# Description: FLOWERS  STICKERS, Count: 61
# Description: BLACK LOVE BIRD CANDLE, Count: 62
# Description: PARTY TIME PENCIL ERASERS, Count: 136
# Description: PINK B'FLY C/COVER W BOBBLES, Count: 7
# Description: PINK UNION JACK  LUGGAGE TAG, Count: 134
# Description: 6 RIBBONS ELEGANT CHRISTMAS , Count: 206
# Description: AGED GLASS SILVER T-LIGHT HOLDER, Count: 355
# Description: BOOM BOX SPEAKER GIRLS, Count: 94
# Description: 6 RIBBONS SHIMMERING PINKS , Count: 202
# Description: JUMBO BAG OWLS, Count: 673
# Description: OWL DOORSTOP, Count: 259
# Description: PAINTED METAL STAR WITH HOLLY BELLS, Count: 122
# Description: PAINTED METAL HEART WITH HOLLY BELL, Count: 105
# Description: ANGEL DECORATION STARS ON DRESS, Count: 141
# Description: JUMBO BAG STRAWBERRY, Count: 850
# Description: STRAWBERRY SHOPPER BAG, Count: 420
# Description: ROUND SNACK BOXES SET OF 4 FRUITS , Count: 611
# Description: ROUND SNACK BOXES SET OF 4 SKULLS, Count: 306
# Description: DOLLY GIRL LUNCH BOX, Count: 881
# Description: GREEN POLKADOT PLATE , Count: 131
# Description: BLUE POLKADOT PLATE , Count: 200
# Description: RED RETROSPOT PLATE , Count: 311
# Description: PINK  POLKADOT PLATE , Count: 187
# Description: FELTCRAFT DOLL MOLLY, Count: 344
# Description: FELTCRAFT CHRISTMAS FAIRY, Count: 339
# Description: SET OF 3 NOTEBOOKS IN PARCEL, Count: 441
# Description: RED RETROSPOT TAPE, Count: 242
# Description: COSY SLIPPER SHOES SMALL  RED , Count: 25
# Description: 6 RIBBONS RUSTIC CHARM, Count: 986
# Description: 12 DAISY PEGS IN WOOD BOX, Count: 84
# Description: 5 HOOK HANGER RED MAGIC TOADSTOOL, Count: 137
# Description: CHRISTMAS CRAFT TREE TOP ANGEL, Count: 473
# Description: CHRISTMAS CRAFT LITTLE FRIENDS, Count: 563
# Description: COSY SLIPPER SHOES SMALL GREEN, Count: 113
# Description: FELTCRAFT DOLL ROSIE, Count: 310
# Description: FELTCRAFT DOLL EMILY, Count: 276
# Description: FELTCRAFT PRINCESS OLIVIA DOLL, Count: 295
# Description: REX CASH+CARRY JUMBO SHOPPER, Count: 967
# Description: FELTCRAFT CUSHION RABBIT, Count: 398
# Description: FELTCRAFT CUSHION BUTTERFLY, Count: 358
# Description: TOTE BAG I LOVE LONDON, Count: 140
# Description: FOLDING UMBRELLA PINKWHITE POLKADOT, Count: 45
# Description: FOLDING UMBRELLA CREAM POLKADOT, Count: 66
# Description: FOLDING UMBRELLA WHITE/RED POLKADOT, Count: 36
# Description: SET 10 LIGHTS NIGHT OWL, Count: 125
# Description: FOLDING UMBRELLA RED/WHITE POLKADOT, Count: 121
# Description: S/4 VALENTINE DECOUPAGE HEART BOX, Count: 132
# Description: SOLDIERS EGG CUP , Count: 439
# Description: RED RETROSPOT MINI CASES, Count: 391
# Description: NaN, Count: 1454
# Description: 60 CAKE CASES VINTAGE CHRISTMAS, Count: 652
# Description: RIBBON REEL CHRISTMAS SOCK BAUBLE, Count: 327
# Description: RIBBON REEL SNOWY VILLAGE, Count: 283
# Description: SET OF 20 VINTAGE CHRISTMAS NAPKINS, Count: 640
# Description: TURQUOISE CHRISTMAS TREE , Count: 4
# Description: RED STAR CARD HOLDER, Count: 154
# Description: WICKER WREATH SMALL, Count: 125
# Description: ADVENT CALENDAR GINGHAM SACK, Count: 253
# Description: FELTCRAFT BUTTERFLY HEARTS, Count: 506
# Description: PARTY CONE CHRISTMAS DECORATION , Count: 115
# Description: WICKER STAR , Count: 419
# Description: VINTAGE SNAP CARDS, Count: 944
# Description: FELTCRAFT 6 FLOWER FRIENDS, Count: 568
# Description: BIRD DECORATION RED RETROSPOT, Count: 134
# Description: CHRISTMAS GINGHAM TREE, Count: 198
# Description: CHRISTMAS GINGHAM STAR, Count: 203
# Description: CHRISTMAS GINGHAM HEART, Count: 55
# Description: PACK OF 12 PINK POLKADOT TISSUES, Count: 191
# Description: FELTCRAFT PRINCESS LOLA DOLL, Count: 428
# Description: PACK OF 12 LONDON TISSUES , Count: 531
# Description: PURPLE DRAWERKNOB ACRYLIC EDWARDIAN, Count: 256
# Description: CHILDREN'S APRON DOLLY GIRL , Count: 320
# Description: CHILDRENS APRON SPACEBOY DESIGN, Count: 573
# Description: CHRISTMAS LIGHTS 10 SANTAS , Count: 166
# Description: PACK OF 60 MUSHROOM CAKE CASES, Count: 408
# Description: 60 CAKE CASES DOLLY GIRL DESIGN, Count: 458
# Description: HAND WARMER BABUSHKA DESIGN, Count: 386
# Description: SET 12 RETRO WHITE CHALK STICKS, Count: 367
# Description: FELTCRAFT HAIRBAND RED AND BLUE, Count: 165
# Description: FELTCRAFT HAIRBAND PINK AND PURPLE, Count: 156
# Description: FELTCRAFT HAIRBANDS PINK AND WHITE , Count: 150
# Description: TV DINNER TRAY DOLLY GIRL, Count: 112
# Description: PLASTERS IN TIN SPACEBOY, Count: 697
# Description: PLASTERS IN TIN WOODLAND ANIMALS, Count: 729
# Description: MAGIC DRAWING SLATE SPACEBOY , Count: 267
# Description: MAGIC DRAWING SLATE GO TO THE FAIR , Count: 71
# Description: MAGIC DRAWING SLATE DOLLY GIRL , Count: 239
# Description: CHARLIE + LOLA RED HOT WATER BOTTLE, Count: 262
# Description: URBAN BLACK RIBBONS , Count: 188
# Description: SET OF 6 T-LIGHTS TOADSTOOLS, Count: 199
# Description: ROTATING LEAVES T-LIGHT HOLDER, Count: 322
# Description: CUPCAKE LACE PAPER SET 6, Count: 192
# Description: TRADITIONAL WOODEN CATCH CUP GAME , Count: 424
# Description: S/6 WOODEN SKITTLES IN COTTON BAG, Count: 243
# Description: RED METAL BEACH SPADE , Count: 232
# Description: BOYS VINTAGE TIN SEASIDE BUCKET, Count: 247
# Description: GIRLS VINTAGE TIN SEASIDE BUCKET, Count: 232
# Description: GREY HEART HOT WATER BOTTLE, Count: 595
# Description: KINGS CHOICE TEA CADDY , Count: 262
# Description: KINGS CHOICE BISCUIT TIN, Count: 192
# Description: METAL SIGN EMPIRE TEA, Count: 230
# Description: FAWN BLUE HOT WATER BOTTLE, Count: 513
# Description: PACK OF 6 BIRDY GIFT TAGS, Count: 420
# Description: CERAMIC STRAWBERRY MONEY BOX, Count: 118
# Description: CERAMIC HEART FAIRY CAKE MONEY BANK, Count: 363
# Description: CERAMIC PIRATE CHEST MONEY BANK, Count: 148
# Description: DOORSTOP RETROSPOT HEART, Count: 304
# Description: RETROSPOT BABUSHKA DOORSTOP, Count: 55
# Description: SWEETHEART WIRE WALL TIDY, Count: 113
# Description: RED RETROSPOT OVEN GLOVE , Count: 463
# Description: NAMASTE SWAGAT INCENSE, Count: 57
# Description: CERAMIC STRAWBERRY DESIGN MUG, Count: 192
# Description: CLASSICAL ROSE SMALL VASE, Count: 15
# Description: HYACINTH BULB T-LIGHT CANDLES, Count: 49
# Description: CHRISTMAS CRAFT WHITE FAIRY , Count: 391
# Description: COSY HOUR CIGAR BOX MATCHES , Count: 159
# Description: RED TEA TOWEL CLASSIC DESIGN, Count: 74
# Description: HEART FILIGREE DOVE  SMALL, Count: 317
# Description: RETROSPOT CHILDRENS APRON, Count: 369
# Description: COLOURING PENCILS BROWN TUBE, Count: 379
# Description: 4 IVORY DINNER CANDLES SILVER FLOCK, Count: 142
# Description: ZINC METAL HEART DECORATION, Count: 552
# Description: GREEN FERN NOTEBOOK, Count: 45
# Description: BLUE PAISLEY NOTEBOOK, Count: 24
# Description: CHRYSANTHEMUM NOTEBOOK, Count: 80
# Description: LARGE CHINESE STYLE SCISSOR, Count: 65
# Description: SMALL CHINESE STYLE SCISSOR, Count: 54
# Description: HANGING GLASS ETCHED TEALIGHT, Count: 12
# Description: COOKING SET RETROSPOT, Count: 31
# Description: KINGS CHOICE GIANT TUBE MATCHES, Count: 69
# Description: PLACE SETTING WHITE STAR, Count: 112
# Description: S/15 SILVER GLASS BAUBLES IN BAG, Count: 64
# Description: FRENCH WC SIGN BLUE METAL, Count: 306
# Description: FAIRY SOAP SOAP HOLDER, Count: 77
# Description: GREEN GIANT GARDEN THERMOMETER, Count: 155
# Description: BLUE GIANT GARDEN THERMOMETER, Count: 189
# Description: VICTORIAN SEWING BOX SMALL , Count: 295
# Description: VICTORIAN SEWING BOX MEDIUM, Count: 268
# Description: SET/10 RED POLKADOT PARTY CANDLES, Count: 392
# Description: WASHROOM METAL SIGN, Count: 371
# Description: BLACK SWEETHEART BRACELET, Count: 48
# Description: DIAMANTE HAIR GRIP PACK/2 BLACK DIA, Count: 11
# Description: BLACK DIAMANTE EXPANDABLE RING, Count: 13
# Description: DIAMANTE HAIR GRIP PACK/2 RUBY, Count: 16
# Description: DIAMANTE HAIR GRIP PACK/2 MONTANA, Count: 11
# Description: BLUE SWEETHEART BRACELET, Count: 27
# Description: PINK SWEETHEART BRACELET, Count: 79
# Description: PURPLE SWEETHEART BRACELET, Count: 50
# Description: RIBBON REEL CHRISTMAS PRESENT , Count: 269
# Description: FIRST AID TIN, Count: 170
# Description: MAKE YOUR OWN MONSOON CARD KIT, Count: 178
# Description: PACK OF 12 HEARTS DESIGN TISSUES , Count: 434
# Description: HEART FILIGREE DOVE LARGE, Count: 261
# Description: SWIRLY CIRCULAR RUBBERS IN BAG, Count: 60
# Description: VINTAGE PAISLEY STATIONERY SET, Count: 453
# Description: SET/10 BLUE POLKADOT PARTY CANDLES, Count: 249
# Description: RIBBON REEL SOCKS AND MITTENS, Count: 141
# Description: CHRISTMAS METAL TAGS ASSORTED , Count: 183
# Description: CHRISTMAS TREE T-LIGHT HOLDER, Count: 9
# Description: STAR  T-LIGHT HOLDER , Count: 31
# Description: HEART T-LIGHT HOLDER , Count: 18
# Description: MINI FUNKY DESIGN TAPES, Count: 94
# Description: STAR WOODEN CHRISTMAS DECORATION, Count: 223
# Description: WOODEN HEART CHRISTMAS SCANDINAVIAN, Count: 557
# Description: CHRISTMAS RETROSPOT TREE WOOD, Count: 179
# Description: SET/9 CHRISTMAS T-LIGHTS SCENTED , Count: 8
# Description: BLUE ROSE FABRIC MIRROR, Count: 92
# Description: THREE CANVAS LUGGAGE TAGS, Count: 48
# Description: RETROSPOT PARTY BAG + STICKER SET, Count: 334
# Description: RETROSPOT SMALL TUBE MATCHES, Count: 160
# Description: 3D CHRISTMAS STAMPS STICKERS , Count: 145
# Description: 36 FOIL HEART CAKE CASES, Count: 209
# Description: PACK OF 6 SWEETIE GIFT BOXES, Count: 105
# Description: CINAMMON SET OF 9 T-LIGHTS, Count: 158
# Description: ORANGE SCENTED SET/9 T-LIGHTS, Count: 89
# Description: RIBBON REEL STRIPES DESIGN , Count: 429
# Description: SET OF 2 TINS JARDIN DE PROVENCE, Count: 101
# Description: MAKE YOUR OWN PLAYTIME CARD KIT, Count: 105
# Description: DINOSAURS  WRITING SET , Count: 291
# Description: SKULLS WRITING SET , Count: 256
# Description: DOORMAT BLACK FLOCK , Count: 201
# Description: CHRISTMAS DECOUPAGE CANDLE, Count: 79
# Description: OFFICE MUG WARMER POLKADOT, Count: 139
# Description: BLACK RECORD COVER FRAME, Count: 384
# Description: RECORD FRAME 7" SINGLE SIZE , Count: 369
# Description: 36 PENCILS TUBE RED RETROSPOT, Count: 345
# Description: 36 PENCILS TUBE WOODLAND, Count: 192
# Description: ROCKING HORSE RED CHRISTMAS , Count: 266
# Description: REGENCY CAKESTAND 3 TIER, Count: 2200
# Description: VINTAGE UNION JACK BUNTING, Count: 491
# Description: RETRO LONGBOARD IRONING BOARD COVER, Count: 107
# Description: 3D DOG PICTURE PLAYING CARDS, Count: 90
# Description: SAVE THE PLANET COTTON TOTE BAG, Count: 177
# Description: PAPER BUNTING WHITE LACE, Count: 342
# Description: GENTLEMAN SHIRT REPAIR KIT , Count: 170
# Description: CARD I LOVE LONDON , Count: 224
# Description: MIRRORED WALL ART FOXY, Count: 9
# Description: MIRRORED WALL ART GENTS, Count: 43
# Description: AIRLINE BAG VINTAGE JET SET WHITE, Count: 126
# Description: POTTING SHED SOW 'N' GROW SET, Count: 2
# Description: AIRLINE BAG VINTAGE WORLD CHAMPION , Count: 152
# Description: PINK HEARTS PAPER GARLAND, Count: 8
# Description: POTTING SHED SEED ENVELOPES, Count: 134
# Description: HI TEC ALPINE HAND WARMER, Count: 113
# Description: POLYESTER FILLER PAD 45x45cm, Count: 144
# Description: CARD DOLLY GIRL , Count: 319
# Description: CARD BILLBOARD FONT, Count: 447
# Description: RAINY LADIES BIRTHDAY CARD, Count: 216
# Description: RED WHITE SCARF  HOT WATER BOTTLE, Count: 16
# Description: SET OF 2 TEA TOWELS APPLE AND PEARS, Count: 292
# Description: LANTERN CREAM GAZEBO , Count: 336
# Description: BLUE BIRDHOUSE DECORATION, Count: 62
# Description: ANTIQUE SILVER TEA GLASS ENGRAVED, Count: 371
# Description: SET OF 2 WOODEN MARKET CRATES, Count: 212
# Description: CLASSIC FRENCH STYLE BASKET NATURAL, Count: 108
# Description: CRAZY DAISY HEART DECORATION, Count: 150
# Description: CARD HOLDER GINGHAM HEART, Count: 181
# Description: SMALL STRIPES CHOCOLATE GIFT BAG , Count: 28
# Description: TRAY, BREAKFAST IN BED, Count: 86
# Description: PIZZA PLATE IN BOX, Count: 188
# Description: PINK HEART DOTS HOT WATER BOTTLE, Count: 11
# Description: PLACE SETTING WHITE HEART, Count: 345
# Description: SET OF 4 NAPKIN CHARMS LEAVES   , Count: 50
# Description: SET OF 4 NAPKIN CHARMS STARS   , Count: 53
# Description: SET OF 4 NAPKIN CHARMS CUTLERY, Count: 131
# Description: CARAVAN SQUARE TISSUE BOX, Count: 165
# Description: BUTTON BOX , Count: 256
# Description: 12 MESSAGE CARDS WITH ENVELOPES, Count: 265
# Description: SMALL RED BABUSHKA NOTEBOOK , Count: 270
# Description: HERB MARKER MINT, Count: 248
# Description: HERB MARKER ROSEMARY, Count: 249
# Description: HERB MARKER BASIL, Count: 250
# Description: HERB MARKER CHIVES , Count: 216
# Description: HERB MARKER PARSLEY, Count: 247
# Description: HERB MARKER THYME, Count: 246
# Description: METAL MERRY CHRISTMAS WREATH, Count: 94
# Description: WHITE CHRISTMAS GARLAND STARS TREES, Count: 66
# Description: RETROSPOT GIANT TUBE MATCHES, Count: 139
# Description: 36 FOIL STAR CAKE CASES , Count: 140
# Description: PACK OF 6 HANDBAG GIFT BOXES, Count: 115
# Description: GARLAND WOODEN HAPPY EASTER, Count: 247
# Description: CALENDAR PAPER CUT DESIGN, Count: 279
# Description: CALENDAR IN SEASON DESIGN, Count: 112
# Description: BLUE PAISLEY TISSUE BOX, Count: 93
# Description: PINK PAISLEY SQUARE TISSUE BOX , Count: 127
# Description: TOAST ITS - HAPPY BIRTHDAY, Count: 109
# Description: SET/10 IVORY POLKADOT PARTY CANDLES, Count: 160
# Description: SKULLS STORAGE BOX SMALL, Count: 44
# Description: JUMBO STORAGE BAG SKULLS, Count: 720
# Description: GARDEN PATH JOURNAL, Count: 66
# Description: BLACK ORANGE SQUEEZER, Count: 21
# Description: SET OF 72 GREEN PAPER DOILIES, Count: 21
# Description: RETROSPOT RED WASHING UP GLOVES, Count: 309
# Description: SMALL LICORICE DES PINK BOWL, Count: 86
# Description: SWISS ROLL TOWEL, CHOCOLATE  SPOTS, Count: 96
# Description: PICNIC BASKET WICKER LARGE, Count: 466
# Description: CREAM SWEETHEART EGG HOLDER, Count: 166
# Description: PINK 3 PIECE POLKADOT CUTLERY SET, Count: 125
# Description: PINK PARTY BAGS, Count: 168
# Description: BLUE PARTY BAGS , Count: 120
# Description: PINK CREAM FELT CRAFT TRINKET BOX , Count: 633
# Description: RED RETROSPOT OVEN GLOVE DOUBLE, Count: 266
# Description: RIDGED GLASS STORAGE JAR CREAM LID, Count: 20
# Description: PACK OF 20 NAPKINS PANTRY DESIGN, Count: 709
# Description: SWEETHEART CAKESTAND 3 TIER, Count: 407
# Description: CHRISTMAS HANGING STAR WITH BELL, Count: 270
# Description: MULTICOLOUR  CONFETTI IN TUBE, Count: 28
# Description: CHOCOLATE 3 WICK MORRIS BOX CANDLE, Count: 72
# Description: SET OF 16 VINTAGE PISTACHIO CUTLERY, Count: 106
# Description: CHRISTMAS TOILET ROLL, Count: 271
# Description: WHITE BELL HONEYCOMB PAPER , Count: 92
# Description:  4 PURPLE FLOCK DINNER CANDLES, Count: 41
# Description: PINK & WHITE BREAKFAST TRAY, Count: 35
# Description: ENGLISH ROSE SPIRIT LEVEL , Count: 119
# Description: LARGE ROUND WICKER PLATTER , Count: 94
# Description: BLACK TEA TOWEL CLASSIC DESIGN, Count: 131
# Description: CHRISTMAS LIGHTS 10 VINTAGE BAUBLES, Count: 222
# Description: ROSES REGENCY TEACUP AND SAUCER , Count: 1138
# Description: T-LIGHT HOLDER HANGING LACE, Count: 84
# Description: HANGING HEART MIRROR DECORATION , Count: 303
# Description: CREAM SLICE FLANNEL CHOCOLATE SPOT , Count: 54
# Description: CREAM SLICE FLANNEL PINK SPOT , Count: 101
# Description: GREEN REGENCY TEACUP AND SAUCER, Count: 1085
# Description: EIGHT PIECE DINOSAUR SET, Count: 39
# Description: HEADS AND TAILS SPORTING FUN, Count: 214
# Description: ASS COL SMALL SAND GECKO P'WEIGHT, Count: 10
# Description: ENAMEL MEASURING JUG CREAM, Count: 403
# Description: 12 PENCILS SMALL TUBE SKULL, Count: 370
# Description: 12 PENCIL SMALL TUBE WOODLAND, Count: 372
# Description: BLUE PAPER PARASOL , Count: 61
# Description: VICTORIAN  METAL POSTCARD SPRING, Count: 186
# Description: METAL 4 HOOK HANGER FRENCH CHATEAU, Count: 506
# Description: BLACK KITCHEN SCALES, Count: 210
# Description: RED KITCHEN SCALES, Count: 577
# Description: IVORY KITCHEN SCALES, Count: 741
# Description: MULTI COLOUR SILVER T-LIGHT HOLDER, Count: 372
# Description: 3 HOOK HANGER MAGIC GARDEN, Count: 170
# Description: ASSORTED COLOUR LIZARD SUCTION HOOK, Count: 64
# Description: JUMBO BAG WOODLAND ANIMALS, Count: 878
# Description: CHILDREN'S CIRCUS PARADE MUG, Count: 151
# Description: PACK 3 FIRE ENGINE/CAR PATCHES, Count: 20
# Description: CARD PSYCHEDELIC APPLES, Count: 269
# Description: IVORY ENCHANTED FOREST PLACEMAT, Count: 93
# Description: PACK OF 6 PANNETONE GIFT BOXES, Count: 182
# Description: MEASURING TAPE BABUSHKA RED, Count: 44
# Description: RED ENCHANTED FOREST PLACEMAT, Count: 113
# Description: CHILDRENS DOLLY GIRL MUG, Count: 216
# Description: TOADSTOOL MONEY BOX, Count: 200
# Description: MAKE YOUR OWN FLOWERPOWER CARD KIT, Count: 211
# Description: PAPER CHAIN KIT LONDON, Count: 99
# Description: MEASURING TAPE BABUSHKA BLUE, Count: 82
# Description: PENCIL CASE LIFE IS BEAUTIFUL, Count: 137
# Description: WOODEN ROUNDERS GARDEN SET , Count: 366
# Description: CHILDS BREAKFAST SET DOLLY GIRL , Count: 204
# Description: CHILDS BREAKFAST SET SPACEBOY , Count: 250
# Description: CAKE PLATE LOVEBIRD WHITE, Count: 222
# Description: WOODEN ADVENT CALENDAR RED, Count: 141
# Description: GREEN CHRISTMAS TREE CARD HOLDER, Count: 197
# Description: STRING OF STARS CARD HOLDER, Count: 15
# Description: SET/12 TAPER CANDLES, Count: 95
# Description: MINT KITCHEN SCALES, Count: 379
# Description: WHITE WOOD GARDEN PLANT LADDER, Count: 447
# Description: GLASS JAR ENGLISH CONFECTIONERY, Count: 241
# Description: GLASS JAR DIGESTIVE BISCUITS, Count: 186
# Description: MILK BOTTLE WITH GLASS STOPPER , Count: 17
# Description: WELCOME  WOODEN BLOCK LETTERS, Count: 193
# Description: SET/4 MODERN VINTAGE COTTON NAPKINS, Count: 24
# Description: VINTAGE UNION JACK APRON, Count: 174
# Description: SWALLOW SQUARE TISSUE BOX, Count: 166
# Description: NO JUNK MAIL METAL SIGN, Count: 275
# Description: SLATE TILE NATURAL HANGING, Count: 166
# Description: VINTAGE GLASS COFFEE CADDY, Count: 26
# Description: SILVER GLASS T-LIGHT SET, Count: 18
# Description: RIDGED GLASS FINGER BOWL, Count: 62
# Description: GLASS  BEURRE DISH, Count: 240
# Description: GIN & TONIC DIET GREETING CARD , Count: 249
# Description: BIRTHDAY CARD, RETRO SPOT, Count: 270
# Description: WRAP RED APPLES , Count: 177
# Description: RED RETROSPOT WRAP , Count: 339
# Description: WRAP CHRISTMAS SCREEN PRINT, Count: 35
# Description: FANCY FONTS BIRTHDAY WRAP, Count: 232
# Description: CLASSIC WHITE FRAME, Count: 16
# Description: BLACK DINER WALL CLOCK, Count: 45
# Description: DOORMAT PEACE ON EARTH BLUE, Count: 32
# Description: BOX OF 24 COCKTAIL PARASOLS, Count: 603
# Description: GROW YOUR OWN PLANT IN A CAN , Count: 62
# Description: PLASTERS IN TIN STRONGMAN, Count: 534
# Description: MINI JIGSAW DINOSAUR , Count: 103
# Description: MINI JIGSAW BAKE A CAKE , Count: 57
# Description: MINI JIGSAW DOLLY GIRL, Count: 141
# Description: WOODEN SCHOOL COLOURING SET, Count: 449
# Description: PACK OF 12 TRADITIONAL CRAYONS, Count: 450
# Description: CARD PARTY GAMES , Count: 236
# Description: BOOZE & WOMEN GREETING CARD , Count: 59
# Description: PACK OF 12 SUKI TISSUES , Count: 372
# Description: PACK OF 12 WOODLAND TISSUES , Count: 277
# Description: PACK OF 12 SKULL TISSUES, Count: 239
# Description: PACK OF 12 CIRCUS PARADE TISSUES , Count: 104
# Description: PACK OF 12 SPACEBOY TISSUES, Count: 228
# Description: LADS ONLY TISSUE BOX, Count: 157
# Description: RED RETROSPOT TISSUE BOX, Count: 214
# Description: GINGERBREAD MAN COOKIE CUTTER, Count: 691
# Description: GIN AND TONIC MUG, Count: 304
# Description: IF YOU CAN'T STAND THE HEAT MUG, Count: 123
# Description: I CAN ONLY PLEASE ONE PERSON MUG, Count: 170
# Description: PINK HEART SHAPE EGG FRYING PAN, Count: 265
# Description: 200 RED + WHITE BENDY STRAWS, Count: 175
# Description: RECIPE BOX RETROSPOT , Count: 499
# Description: RECIPE BOX PANTRY YELLOW DESIGN, Count: 1180
# Description: RECIPE BOX BLUE SKETCHBOOK DESIGN, Count: 371
# Description: 20 DOLLY PEGS RETROSPOT, Count: 237
# Description: NO SINGING METAL SIGN, Count: 505
# Description: BISCUIT TIN VINTAGE RED, Count: 177
# Description: EMERGENCY FIRST AID TIN , Count: 253
# Description: POLKADOT PEN, Count: 170
# Description: DECORATIVE PLANT POT WITH FRIEZE, Count: 29
# Description: FRENCH BLUE METAL DOOR SIGN 5, Count: 164
# Description: CHEST OF DRAWERS GINGHAM HEART , Count: 101
# Description: RED RETROSPOT CAKE STAND, Count: 584
# Description: JOY WOODEN BLOCK LETTERS, Count: 91
# Description: NOEL WOODEN BLOCK LETTERS , Count: 136
# Description: PEACE WOODEN BLOCK LETTERS, Count: 114
# Description: OFFICE MUG WARMER BLACK+SILVER , Count: 151
# Description: SET OF 2 CHRISTMAS DECOUPAGE CANDLE, Count: 164
# Description: COSMETIC BAG VINTAGE ROSE PAISLEY, Count: 100
# Description: PINK ROSE FABRIC MIRROR, Count: 62
# Description: SILVER PLATE CANDLE BOWL SMALL, Count: 57
# Description: SMALL REGAL  SILVER CANDLEPOT , Count: 24
# Description: ANTIQUE TALL SWIRLGLASS TRINKET POT, Count: 210
# Description: ANTIQUE GLASS PEDESTAL BOWL, Count: 237
# Description: GUMBALL MAGAZINE RACK, Count: 246
# Description: RED FLOWER CROCHET FOOD COVER, Count: 112
# Description: CHERRY CROCHET FOOD COVER, Count: 106
# Description: STRAWBERRY RAFFIA FOOD COVER, Count: 168
# Description: POLKA DOT RAFFIA FOOD COVER, Count: 91
# Description: DOORMAT SPOTTY HOME SWEET HOME, Count: 489
# Description: T-LIGHT GLASS FLUTED ANTIQUE, Count: 361
# Description: SILVER  CANDLEPOT JARDIN , Count: 9
# Description: POLKADOT MUG PINK , Count: 13
# Description: PAPER BUNTING COLOURED LACE, Count: 243
# Description: ANTIQUE GLASS HEART DECORATION , Count: 41
# Description: SET OF 6 KASHMIR FOLKART BAUBLES, Count: 87
# Description: CHRISTMAS RETROSPOT ANGEL WOOD, Count: 207
# Description: CHRISTMAS RETROSPOT STAR WOOD, Count: 200
# Description: HEART WOODEN CHRISTMAS DECORATION, Count: 226
# Description: LARGE HANGING IVORY & RED WOOD BIRD, Count: 97
# Description: SMALL HANGING IVORY/RED WOOD BIRD, Count: 275
# Description: GRAND CHOCOLATECANDLE, Count: 303
# Description: FAIRY CAKE BIRTHDAY CANDLE SET, Count: 104
# Description: 3 HOOK PHOTO SHELF ANTIQUE WHITE, Count: 403
# Description: CREAM SWEETHEART WALL CABINET, Count: 5
# Description: DOORMAT ENGLISH ROSE , Count: 416
# Description: DOORMAT UNION FLAG, Count: 627
# Description: ROMANTIC IMAGES NOTEBOOK SET, Count: 33
# Description: CURIOUS  IMAGES NOTEBOOK SET, Count: 12
# Description: VINTAGE KEEPSAKE BOX PARIS DAYS, Count: 56
# Description: RED GINGHAM ROSE JEWELLERY BOX, Count: 302
# Description: BLUE CHARLIE+LOLA PERSONAL DOORSIGN, Count: 115
# Description: CHARLIE+LOLA"EXTREMELY BUSY" SIGN, Count: 106
# Description: CHARLOTTE BAG SUKI DESIGN, Count: 911
# Description: LOLITA  DESIGN  COTTON TOTE BAG, Count: 55
# Description: LETS GO SHOPPING COTTON TOTE BAG, Count: 78
# Description: PAINT YOUR OWN CANVAS SET, Count: 228
# Description: CAMOUFLAGE LED TORCH, Count: 171
# Description: BLUE DRAGONFLY HELICOPTER, Count: 47
# Description: YELLOW SHARK HELICOPTER, Count: 55
# Description: RED SHARK HELICOPTER, Count: 36
# Description: TOOL BOX SOFT TOY , Count: 108
# Description: DOCTOR'S BAG SOFT TOY, Count: 74
# Description: CARRIAGE, Count: 143
# Description: JUMBO BAG SCANDINAVIAN PAISLEY, Count: 148
# Description: JUMBO BAG TOYS , Count: 532
# Description: DECORATIVE ROSE BATHROOM BOTTLE, Count: 164
# Description: DECORATIVE CATS BATHROOM BOTTLE, Count: 188
# Description: RAIN PONCHO RETROSPOT, Count: 252
# Description: CHRISTMAS TREE DECORATION WITH BELL, Count: 126
# Description: CHRISTMAS TREE HEART DECORATION, Count: 184
# Description: CHRISTMAS TREE STAR DECORATION, Count: 200
# Description: CHRISTMAS HANGING TREE WITH BELL, Count: 123
# Description: GLITTER STAR GARLAND WITH BELLS , Count: 64
# Description: GLITTER CHRISTMAS TREE WITH BELLS, Count: 108
# Description: LILAC DIAMANTE PEN IN GIFT BOX, Count: 63
# Description: HEARTS GIFT TAPE, Count: 96
# Description: CAKES AND BOWS GIFT  TAPE, Count: 93
# Description: BINGO SET, Count: 387
# Description: GARDEN METAL SIGN , Count: 30
# Description: UNION STRIPE WITH FRINGE  HAMMOCK, Count: 211
# Description: SUKI  SHOULDER BAG, Count: 532
# Description: SKULLS DESIGN FLANNEL, Count: 104
# Description: KITTENS DESIGN FLANNEL, Count: 101
# Description: SET OF 6 STRAWBERRY CHOPSTICKS, Count: 145
# Description: MODERN FLORAL STATIONERY SET, Count: 376
# Description: BOHEMIAN COLLAGE STATIONERY SET, Count: 213
# Description: FLORAL FOLK STATIONERY SET, Count: 433
# Description: ROBOT BIRTHDAY CARD, Count: 359
# Description: CHRISTMAS CARD SCREEN PRINT , Count: 64
# Description: CHRISTMAS PUDDING TRINKET POT , Count: 265
# Description: CHOC TRUFFLE GOLD TRINKET POT , Count: 76
# Description: BROWN  PIRATE TREASURE CHEST , Count: 148
# Description: SMALL WHITE RETROSPOT MUG IN BOX , Count: 94
# Description: 6 RIBBONS EMPIRE  , Count: 227
# Description: RIBBON REEL POLKADOTS , Count: 161
# Description: RIBBON REEL FLORA + FAUNA , Count: 141
# Description: PAPER BUNTING RETROSPOT, Count: 812
# Description: LADLE LOVE HEART RED , Count: 9
# Description: LADLE LOVE HEART PINK, Count: 13
# Description: ANGEL DECORATION 3 BUTTONS , Count: 172
# Description: STAR DECORATION RUSTIC, Count: 152
# Description: HEART DECORATION WITH PEARLS , Count: 276
# Description: HEART DECORATION RUSTIC HANGING , Count: 363
# Description: HEART GARLAND RUSTIC PADDED, Count: 95
# Description: FAMILY ALBUM WHITE PICTURE FRAME, Count: 390
# Description: CAKE STAND VICTORIAN FILIGREE SMALL, Count: 126
# Description: LOCAL CAFE MUG, Count: 117
# Description: MILK PAN RED RETROSPOT, Count: 148
# Description: FRYING PAN UNION FLAG, Count: 213
# Description: EASTER DECORATION NATURAL CHICK, Count: 71
# Description: WASH BAG VINTAGE ROSE PAISLEY, Count: 87
# Description: PIG KEYRING WITH LIGHT & SOUND , Count: 83
# Description: COFFEE MUG DOG + BALL DESIGN, Count: 205
# Description: COFFEE MUG CAT + BIRD DESIGN, Count: 270
# Description: TEA COSY RED  STRIPE, Count: 123
# Description: OFFICE MUG WARMER CHOC+BLUE, Count: 137
# Description: HEART DECORATION PAINTED ZINC , Count: 235
# Description: DOVE DECORATION PAINTED ZINC , Count: 84
# Description: PARTY PIZZA DISH BLUE POLKADOT, Count: 75
# Description: TEA BAG PLATE RED RETROSPOT, Count: 364
# Description: CHARLOTTE BAG PINK POLKADOT, Count: 777
# Description: GLASS JAR KINGS CHOICE, Count: 88
# Description: GLASS JAR DAISY FRESH COTTON WOOL, Count: 279
# Description: AIRLINE BAG VINTAGE JET SET BROWN, Count: 173
# Description: WALL TIDY RETROSPOT , Count: 296
# Description: TOY TIDY SPACEBOY  , Count: 297
# Description: PAPERWEIGHT KINGS CHOICE , Count: 24
# Description: MAGNETS PACK OF 4 RETRO PHOTO, Count: 135
# Description: LIPSTICK PEN RED, Count: 282
# Description: TOOTHPASTE TUBE PEN, Count: 209
# Description: ENAMEL WATERING CAN CREAM, Count: 212
# Description: WATERING CAN PINK BUNNY, Count: 287
# Description: SET OF 9 BLACK SKULL BALLOONS, Count: 231
# Description: TV DINNER TRAY AIR HOSTESS , Count: 107
# Description: EMPIRE UNION JACK TV DINNER TRAY, Count: 128
# Description: WATERING CAN GARDEN MARKER, Count: 129
# Description: BIRDHOUSE GARDEN MARKER , Count: 141
# Description: DAISY GARDEN MARKER, Count: 98
# Description: SET OF 2 TINS VINTAGE BATHROOM , Count: 101
# Description: CHILDS GARDEN SPADE PINK, Count: 88
# Description: CHILDS GARDEN RAKE PINK, Count: 73
# Description: CHILDS GARDEN BRUSH PINK, Count: 90
# Description: MINI JIGSAW BUNNIES, Count: 77
# Description: HOLIDAY FUN LUDO, Count: 222
# Description: TRADITIONAL MODELLING CLAY, Count: 391
# Description: CARDHOLDER GINGHAM STAR, Count: 81
# Description: WOODEN CROQUET GARDEN SET, Count: 307
# Description: SET OF 4 NAPKIN CHARMS HEARTS, Count: 152
# Description: RED BABY BUNTING , Count: 235
# Description: FRENCH KITCHEN SIGN BLUE METAL, Count: 172
# Description: SET OF 6 RIBBONS VINTAGE CHRISTMAS, Count: 440
# Description: FUNKY DIVA PEN, Count: 237
# Description: SMALL PURPLE BABUSHKA NOTEBOOK , Count: 256
# Description: LARGE RED BABUSHKA NOTEBOOK , Count: 165
# Description: LARGE PURPLE BABUSHKA NOTEBOOK  , Count: 181
# Description: CHALKBOARD KITCHEN ORGANISER, Count: 10
# Description: FLUTED ANTIQUE CANDLE HOLDER, Count: 209
# Description: CARD MOTORBIKE SANTA, Count: 271
# Description: CARD CHRISTMAS VILLAGE, Count: 249
# Description: CREAM WALL PLANTER HEART SHAPED, Count: 161
# Description: VINTAGE CREAM DOG FOOD CONTAINER, Count: 429
# Description: BREAD BIN DINER STYLE IVORY, Count: 406
# Description: LOVE HEART NAPKIN BOX , Count: 69
# Description: NUMBER TILE COTTAGE GARDEN 8, Count: 20
# Description: YELLOW GIANT GARDEN THERMOMETER, Count: 119
# Description: METAL DECORATION NAUGHTY CHILDREN , Count: 146
# Description: 36 DOILIES DOLLY GIRL, Count: 92
# Description: CIRCUS PARADE CHILDRENS EGG CUP , Count: 151
# Description: BLUE VICTORIAN FABRIC OVAL BOX, Count: 100
# Description: RED VICTORIAN FABRIC OVAL BOX, Count: 98
# Description: SET OF 3 BIRD LIGHT PINK FEATHER , Count: 236
# Description: PINK/WHITE CHRISTMAS TREE 60CM, Count: 43
# Description: PINK AND WHITE CHRISTMAS TREE 120CM, Count: 34
# Description: PINK CHRISTMAS FLOCK DROPLET , Count: 3
# Description: ACRYLIC JEWEL ICICLE, PINK, Count: 20
# Description: SMALLFOLKART BAUBLE CHRISTMAS DEC, Count: 42
# Description: FOLKART ZINC HEART CHRISTMAS DEC, Count: 251
# Description: ROSE FOLKART HEART DECORATIONS, Count: 93
# Description: CERAMIC CAKE STAND + HANGING CAKES, Count: 180
# Description: CONDIMENT TRAY 4 BOWLS AND 4 SPOONS, Count: 27
# Description: TEA TIME OVEN GLOVE, Count: 322
# Description: SCOTTIES CHILDRENS APRON, Count: 57
# Description: PINK FAIRY CAKE CHILDRENS APRON, Count: 501
# Description: SCOTTIE DOGS BABY BIB, Count: 248
# Description: DOORMAT WELCOME PUPPIES, Count: 291
# Description: HANGING JAM JAR T-LIGHT HOLDER, Count: 359
# Description: SET OF 6 HALLOWEEN GHOST T-LIGHTS, Count: 85
# Description: IVORY PILLAR CANDLE SILVER FLOCK, Count: 79
# Description: IVORY PILLAR CANDLE GOLD FLOCK, Count: 31
# Description: SET/3 ROSE CANDLE IN JEWELLED BOX, Count: 119
# Description: SET/3 OCEAN SCENT CANDLE JEWEL BOX, Count: 119
# Description: SET/3 VANILLA SCENTED CANDLE IN BOX, Count: 172
# Description: SET/3 CHRISTMAS DECOUPAGE CANDLES, Count: 71
# Description: TUMBLER, BAROQUE, Count: 7
# Description: TUMBLER, NEW ENGLAND, Count: 14
# Description: LAUNDRY 15C METAL SIGN, Count: 356
# Description: HOT BATHS METAL SIGN, Count: 643
# Description: METAL SIGN,CUPCAKE SINGLE HOOK, Count: 239
# Description: METAL SIGN CUPCAKE SINGLE HOOK, Count: 113
# Description: CHARLIE+LOLA RED HOT WATER BOTTLE , Count: 168
# ...
# Description: VINTAGE DOILY TRAVEL SEWING KIT, Count: 433
# Description: SET 12 COLOUR PENCILS LOVE LONDON, Count: 175
# Description: SET 36 COLOUR PENCILS LOVE LONDON, Count: 129
# Description: EMBROIDERED RIBBON REEL RUBY , Count: 33
# Description: EMBROIDERED RIBBON REEL EMILY , Count: 102
# Description: EMBROIDERED RIBBON REEL REBECCA , Count: 63
# Description: SET 36 COLOURING PENCILS DOILY, Count: 155
# Description: SET 12 COLOUR PENCILS DOLLY GIRL , Count: 241
# Description: PLAYING CARDS I LOVE LONDON , Count: 122
# Description: SET 36 COLOUR PENCILS DOLLY GIRL, Count: 154
# Description: EMBROIDERED RIBBON REEL ROSIE, Count: 58
# Description: EMBROIDERED RIBBON REEL DAISY , Count: 72
# Description: EMBROIDERED RIBBON REEL SALLY , Count: 75
# Description: EMBROIDERED RIBBON REEL RACHEL , Count: 46
# Description: MINI PLAYING CARDS GYMKHANA, Count: 126
# Description: MINI PLAYING CARDS DOLLY GIRL , Count: 133
# Description: MINI PLAYING CARDS FUN FAIR , Count: 68
# Description: MINI PLAYING CARDS BUFFALO BILL , Count: 129
# Description: EMBROIDERED RIBBON REEL SUSIE , Count: 71
# Description: SET 10 CARD PERFECT NATIVITY 17089, Count: 4
# Description: Dagamed, Count: 1
# Description: ROUND CACTUS CANDLE, Count: 4
# Description: DOLLY GIRL MINI RUCKSACK, Count: 2
# Description: SPACEBOY MINI RUCKSACK, Count: 4
# Description: PLAYING CARDS VINTAGE DOILY , Count: 93
# Description: LARGE BLACK DIAMANTE HAIRSLIDE, Count: 1
# Description: SET 10 CARDS CHRISTMAS ROBIN 17095, Count: 3
# Description: PACK OF 12 CHRISTMAS FUN CARDS, Count: 41
# Description: SET 10 CARDS SNOWY SNOWDROPS  17100, Count: 4
# Description: SET 10 CARDS CHEERFUL ROBIN 17065, Count: 10
# Description: EMBROIDERED RIBBON REEL SOPHIE  , Count: 45
# Description: EMBROIDERED RIBBON REEL CLAIRE, Count: 24
# Description: VINTAGE DOILY DELUXE SEWING KIT , Count: 219
# Description: SET 10 CARDS ROBIN WATERPUMP  17096, Count: 2
# Description: SET 10 CARDS FILIGREE BAUBLE 16961, Count: 4
# Description: SMOKEY GREY COLOUR GLASS, Count: 16
# Description: SWEETHEART BIRD HOUSE, Count: 108
# Description: TUSCAN VILLA DOVECOTE, Count: 4
# Description: CARD HOLDER LOVE BIRD SMALL, Count: 74
# Description: HEART TRELLISTRIPLE T-LIGHT HOLDER, Count: 5
# Description: VINTAGE LEAF CHOPPING BOARD  , Count: 47
# Description: POPPY FIELDS CHOPPING BOARD, Count: 46
# Description: RED APPLES CHOPPING BOARD   , Count: 47
# Description: SIX DRAWER OFFICE TIDY, Count: 28
# Description: VEGETABLE GARDEN CHOPPING BOARD, Count: 23
# Description: SET 10 CARDS CHRISTMAS TREE 16955, Count: 5
# Description:  NINE DRAWER OFFICE TIDY, Count: 34
# Description: CARD HOLDER LOVE BIRD LARGE , Count: 92
# Description: HORSE & PONY WALL ART, Count: 17
# Description: BICYCLE SAFTEY WALL ART, Count: 39
# Description: STOP FOR TEA WALL ART, Count: 41
# Description: WALL ART CLASSIC PUDDINGS , Count: 151
# Description: BUFFALO BILL WALL ART , Count: 16
# Description: WALL ART WORK REST AND PLAY  , Count: 31
# Description: WALL ART LOVES' SECRET , Count: 40
# Description: DOG AND BALL WALL ART, Count: 4
# Description: DOG LICENCE WALL ART, Count: 29
# Description: WALL ART GARDEN HAVEN , Count: 36
# Description: 70'S ALPHABET WALL ART, Count: 15
# Description: SPACEBOY WALL ART, Count: 13
# Description: KEEP CALM WALL ART , Count: 20
# Description: WALL ART ONLY ONE PERSON , Count: 87
# Description: WALL ART VINTAGE HEART, Count: 33
# Description: CAT AND BIRD WALL ART, Count: 4
# Description: TREASURE AHOY WALL ART, Count: 16
# Description: WALL ART BIG LOVE , Count: 114
# Description: ANIMALS AND NATURE WALL ART, Count: 17
# Description: HANGING  BUTTERFLY T-LIGHT HOLDER, Count: 80
# Description: DOLLY GIRL WALL ART, Count: 11
# Description: VILLAGE SHOW WALL ART, Count: 18
# Description: WALL ART MID CENTURY MODERN , Count: 21
# Description: historic computer difference?....se, Count: 1
# Description: WALL ART THE MAGIC FOREST , Count: 13
# Description: I LOVE LONDON WALL ART, Count: 2
# Description: WALL ART KEEP CALM , Count: 86
# Description: WALL ART BICYCLE SAFTEY , Count: 3
# Description: WALL ART BUFFALO BILL , Count: 39
# Description: WALL ART VILLAGE SHOW , Count: 68
# Description: WALL ART STOP FOR TEA , Count: 223
# Description: WALL ART DOG LICENCE , Count: 117
# Description: WALL ART SPACEBOY, Count: 37
# Description: SET 10 MINI SANTA & SNOWMAN  17087, Count: 2
# Description: SET 10 CARDS DINKY TREE 17076, Count: 16
# Description: WALL ART I LOVE LONDON , Count: 32
# Description: WALL ART 70'S ALPHABET , Count: 77
# Description: Lighthouse Trading zero invc incorr, Count: 1
# Description: Incorrect stock entry., Count: 1
# Description: incorrect stock entry., Count: 2
# Description: KEY RING BASEBALL BOOT ASSORTED , Count: 107
# Description: WALL ART HORSE & PONY , Count: 47
# Description: WALL ART ANIMALS AND NATURE , Count: 34
# Description: PINK HORSE SOCK PUPPET KIT, Count: 19
# Description: HEART TRELLIS TRIPLE T-LIGHT HOLDER, Count: 31
# Description: WALL ART CAT AND BIRD , Count: 40
# Description: TUSCAN VILLA FEEDING STATION, Count: 7
# Description: KEY RING BASEBALL BOOT UNION JACK, Count: 116
# Description: WALL ART BICYCLE SAFETY, Count: 179
# Description: VINTAGE  2 METRE FOLDING RULER, Count: 156
# Description: michel oops, Count: 1
# Description: WALL ART DOLLY GIRL , Count: 26
# Description: SET 10 CARDS 12 DAYS OF XMAS 17059, Count: 1
# Description: SET 10 CARDS POINSETTIA 17093, Count: 2
# Description: SET 10 CARDS CHRISTMAS HOLLY  17259, Count: 3
# Description:  I LOVE LONDON MINI RUCKSACK, Count: 1
# Description: SET 36 COLOURING PENCILS DOILEY, Count: 1
# Description: SET 12 COLOURING PENCILS DOILEY, Count: 1
# Description: WOODLAND MINI RUCKSACK , Count: 2
# Description: WALL ART DOG AND BALL , Count: 28
# Description: wrongly coded 20713, Count: 2
# Description: wrongly coded-23343, Count: 1
# Description: WALL ART , LOVES' SECRET , Count: 2
# Description: WALL ART,ONLY ONE PERSON , Count: 1
# Description: WALL ART ,PUDDINGS , Count: 2
# Description: stock check, Count: 2
# Description: crushed boxes, Count: 1
# Description: SET 10 MINICARDS CUTE SNOWMAN 17071, Count: 2
# Description: TUSCAN VILLA BIRD TABLE , Count: 11
# Description: N0 SINGING METAL SIGN, Count: 49
# Description: WET/MOULDY, Count: 1
# Description: can't find, Count: 1
# Description: UBO-LIGHT TRIOBASE PURPLE, Count: 3
# Description: SILVER 2 STRAND NECKLACE-LEAF CHARM, Count: 2
# Description: SILVER M.O.P. ORBIT NECKLACE, Count: 6
# Description: GOLD M.O.P. ORBIT NECKLACE, Count: 2
# Description: TUSCAN VILLA DOVECOTE BIRD FEEDER, Count: 24
# Description: WALL ART , THE MAGIC FOREST , Count: 1
# Description: CREAM BUNNY EASTER EGG BASKET, Count: 3
# Description: PINK BUNNY EASTER EGG BASKET, Count: 4
# Description: BLUE BUNNY EASTER EGG BASKET, Count: 3
# Description: WALL ART TREASURE AHOY , Count: 26
# Description: S/4 BLACK DISCO PARTITION PANEL, Count: 1
# Description: BLACK VINT ART DEC CRYSTAL BRACELET, Count: 2
# Description: mouldy, Count: 1
# Description: BOX OF 6 CHRISTMAS CAKE DECORATIONS, Count: 224
# Description: HENRIETTA HEN MUG , Count: 46
# Description: MILK MAIDS MUG , Count: 38
# Description: EGG CUP MILKMAID INGRID, Count: 76
# Description: PINK HANGING HEART T-LIGHT HOLDER, Count: 79
# Description: EGG CUP HENRIETTA HEN PINK, Count: 39
# Description: Wet pallet-thrown away, Count: 1
# Description: Had been put aside., Count: 1
# Description: SWEET HEART CAKE CARRIER, Count: 50
# Description: T-LIGHT HOLDER HANGING LOVE BIRD, Count: 103
# Description: OVAL  MINI PORTRAIT FRAME, Count: 51
# Description: HEART MINI PORTRAIT FRAME, Count: 88
# Description: SQUARE MINI PORTRAIT FRAME, Count: 54
# Description: PEARLISED IVORY HEART LARGE , Count: 39
# Description: SET 10 CARD KRAFT REINDEER 17084, Count: 14
# Description: DOLLY CABINET 2 DRAWERS , Count: 21
# Description: EGG CUP MILKMAID HELGA , Count: 65
# Description: MEDIUM PARLOUR PICTURE FRAME , Count: 35
# Description: VINTAGE ZINC WATERING CAN, Count: 8
# Description: VINTAGE ZINC WATERING CAN SMALL, Count: 8
# Description: LARGE PARLOUR PICTURE FRAME, Count: 30
# Description: SMALL PARLOUR PICTURE FRAME, Count: 34
# Description: EGG CUP HENRIETTA HEN CREAM , Count: 49
# Description: EGG CUP MILKMAID HEIDI, Count: 85
# Description: VINTAGE ZINC PLANTER  , Count: 11
# Description: WIRE EGG BASKET , Count: 45
# Description: PEARLISED IVORY HEART SMALL , Count: 32
# Description: DOLLY CABINET 3 DRAWERS , Count: 34
# Description: SNACK TRAY I LOVE LONDON, Count: 37
# Description: Sale error, Count: 1
# Description: DECROTIVEVINTAGE COFFEE GRINDER BOX, Count: 6
# Description: High Resolution Image, Count: 3
# Description: LANDMARK FRAME LONDON BRIDGE , Count: 55
# Description: LANDMARK FRAME COVENT GARDEN , Count: 57
# Description: LANDMARK FRAME OXFORD STREET, Count: 59
# Description: LANDMARK FRAME BAKER STREET , Count: 32
# Description: LANDMARK FRAME NOTTING HILL , Count: 54
# Description: MINI LIGHTS WOODLAND MUSHROOMS, Count: 223
# Description: LANDMARK FRAME CAMDEN TOWN , Count: 69
# Description: GARLAND, VINTAGE BELLS, Count: 10
# Description: VINTAGE JINGLE BELLS HEART, Count: 80
# Description: VINTAGE JINGLE BELLS WREATH, Count: 28
# Description: WOODLAND LARGE BLUE FELT HEART, Count: 13
# Description: WOODLAND LARGE PINK FELT HEART, Count: 13
# Description: WOODLAND LARGE RED FELT HEART, Count: 22
# Description: ANTIQUE HEART SHELF UNIT, Count: 80
# Description: WOODLAND SMALL RED FELT HEART, Count: 52
# Description: SWEETHEART WALL TIDY , Count: 47
# Description: ROCOCO WALL MIRROR WHITE, Count: 57
# Description: SET 12 VINTAGE DOILY CHALK , Count: 115
# Description: BOTANICAL GARDENS WALL CLOCK , Count: 96
# Description: VINTAGE BELLS GARLAND, Count: 155
# Description: ROCOCO WALL MIROR, Count: 1
# Description: TRADITIONAL PICK UP STICKS GAME , Count: 293
# Description: SET OF 3 MINI HANGING PORTRAITS, Count: 2
# Description: TRADITIONAL NAUGHTS & CROSSES, Count: 268
# Description: TRADTIONAL ALPHABET STAMP SET, Count: 203
# Description: SET 4 PICNIC CUTLERY BLUEBERRY, Count: 9
# Description: THREE MINI HANGING FRAMES, Count: 58
# Description: WOODLAND SMALL BLUE FELT HEART, Count: 38
# Description: Amazon Adjustment, Count: 1
# Description: wrongly marked 23343, Count: 1
# Description: 20713 wrongly marked, Count: 1
# Description: SET 10 CARDS WISHING TREE 17116, Count: 7
# Description: STRAWBERRY CERAMIC TRINKET POT, Count: 134
# Description: VINTAGE DOILY JUMBO BAG RED , Count: 269
# Description: LUNCH BAG PAISLEY PARK  , Count: 339
# Description: JUMBO BAG PAISLEY PARK, Count: 355
# Description: UBO-LIGHT TRIOBASE BLUE, Count: 2
# Description: re-adjustment, Count: 1
# Description: SET OF 36 VINTAGE CHRISTMAS DOILIES, Count: 9
# Description: SET OF 36 SPACEBOY PAPER DOILIES, Count: 9
# Description: SET OF 36 DOLLY GIRL PAPER DOILIES, Count: 16
# Description: Breakages, Count: 1
# Description: DECORATIVE VINTAGE COFFEE  BOX, Count: 23
# Description: SET OF 36 PANTRY PAPER DOILIES, Count: 34
# Description: SET 4 PICNIC CUTLERY FONDANT, Count: 6
# Description: Marked as 23343, Count: 1
# Description: 20713, Count: 1
# Description: wrongly coded 23343, Count: 1
# Description: WOODLAND SMALL PINK FELT HEART, Count: 31
# Description: SET 10 CARDS PRINTED GRAPHIC 17219, Count: 4
# Description: SET 10 CHRISTMAS CARDS HOHOHO 16956, Count: 4
# Description: SET 10 CARD SNOWMAN 16965, Count: 4
# Description: Found by jackie, Count: 1
# Description: SILVER RECORD COVER FRAME, Count: 41
# Description: Damages, Count: 1
# Description: CLASSIC CHROME BICYCLE BELL , Count: 201
# Description: SET 4 PICNIC CUTLERY CHERRY , Count: 9
# Description: SET OF 3 PANTRY WOODEN SPOONS, Count: 41
# Description: PANTRY KITCHEN THERMOMETER , Count: 31
# Description: CHECK, Count: 3
# Description: SET 10 CARDS TRIANGLE ICONS  17220, Count: 1
# Description: SET 10 CARDS WORLD CHILDREN 17067, Count: 3
# Description: SET 10 CARDS CHRISTMAS BAUBLE 16954, Count: 1
# Description: Unsaleable, destroyed., Count: 9
# Description: wrongly marked, Count: 1
# Description: dotcom sales, Count: 1
# Description: had been put aside, Count: 5
# Description: LIGHT DECORATION BATTERY OPERATED, Count: 1
# Description: KEEP CALM BIRTHDAY WRAP, Count: 2
# Description: RUBY GLASS CLUSTER NECKLACE, Count: 1
# Description: WRAP KEEP CALM BIRTHDAY, Count: 36
# Description: SET 10 CARDS RUDOLPHS NOSE 17097, Count: 3
# Description: LUNCH BAG RED VINTAGE DOILY, Count: 134
# Description: BLACK SIL'T SQU CANDLE PLATE , Count: 2
# Description: damages wax, Count: 2
# Description: ANT SILVER TURQUOISE BOUDICCA RING, Count: 1
# Description: PINK POLKADOT PLATE , Count: 25
# Description: water damaged, Count: 1
# Description: ST GEORGE SET OF 10 PARTY LIGHTS, Count: 2
# Description: WRAP A PRETTY THANK YOU, Count: 2
# Description: CLASSIC CROME BICYCLE BELL , Count: 2
# Description: DOILY THANK YOU CARD, Count: 59
# Description: A PRETTY THANK YOU CARD, Count: 36
# Description: SET 10 CARDS JINGLE BELLS 17217, Count: 7
# Description: TUSCAN VILLA BIRD FEEDER, Count: 9
# Description: PAPER BUNTING VINTAGE PARTY, Count: 48
# Description: PAPER BUNTING PAISLEY PARK, Count: 34
# Description: Wrongly mrked had 85123a in box, Count: 1
# Description: wrongly marked carton 22804, Count: 1
# Description: SET 10 CARDS DAVID'S MADONNA 17074, Count: 4
# Description: SET 10 CARDS XMAS GRAPHIC  17218, Count: 2
# Description: LARGE PARLOUR FRAME, Count: 2
# Description: MEDIUM PARLOUR FRAME , Count: 2
# Description: SMALL PARLOUR FRAME, Count: 2
# Description: SET 10 CARDS 3 WISE MEN 17107, Count: 1
# Description: FLOWER SHOP DESIGN MUG, Count: 1
# Description: ROSE FLOWER CANDLE+INCENSE 16X16CM, Count: 2
# Description: WHITE CHRISTMAS TREE 60CM, Count: 2
# Description: missing?, Count: 1
# Description: PAISLEY PARK CARD, Count: 41
# Description: PACK 3 BOXES CHRISTMAS PANETTONE, Count: 25
# Description: PACK OF 6 PANETTONE GIFT BOXES, Count: 19
# Description: PACK 3 BOXES BIRD PANETTONE , Count: 31
# Description: COLOURED GLASS STAR T-LIGHT HOLDER, Count: 61
# Description: wet rusty, Count: 2
# Description: SET 10 CARDS DECK THE HALLS 16960, Count: 2
# Description: 12 HANGING EGGS HAND PAINTED, Count: 10
# Description: SET OF 6 EASTER RAINBOW CHICKS, Count: 1
# Description: amazon adjust, Count: 1
# Description: ???lost, Count: 1
# Description: DUSTY PINK CHRISTMAS TREE 60CM, Count: 2
# Description: IVORY RETRO KITCHEN WALL CLOCK, Count: 34
# Description: dotcomstock, Count: 1
# Description: SET 10 CARD CHRISTMAS STAMPS 16963, Count: 1
# Description: John Lewis, Count: 1
# Description: sold with wrong barcode, Count: 1
# Description: WHITE MOROCCAN METAL LANTERN, Count: 27
# Description: CAT WITH SUNGLASSES BLANK CARD, Count: 1
# Description: BLUE RETRO KITCHEN WALL CLOCK, Count: 18
# Description: dotcom adjust, Count: 1
# Description: RED RETRO KITCHEN WALL CLOCK, Count: 23
# Description: rusty thrown away, Count: 1
# Description: rusty throw away, Count: 2
# Description: check?, Count: 1
# Description: PURPLE FINE BEAD NECKLACE W TASSEL, Count: 3
# Description: HAND PAINTED HANGING EASTER EGG, Count: 3
# Description: ?? missing, Count: 1
# Description: wet pallet, Count: 3
# Description: ????missing, Count: 1
# Description: ???missing, Count: 2
# Description: PAINT YOUR OWN EGGS IN CRATE, Count: 5
# Description: AMAZON, Count: 3
# Description: BICYCLE PUNCTURE REPAIR KIT , Count: 124
# Description: CLASSIC BICYCLE CLIPS , Count: 106
# Description: CROCHET LILAC/RED BEAR KEYRING, Count: 1
# Description: SILVER AND BLACK ORBIT NECKLACE, Count: 2
# Description: LARGE HEART FLOWERS HOOK   , Count: 1
# Description: GIN AND TONIC DIET METAL SIGN, Count: 50
# Description: SNACK TRAY RED GINGHAM, Count: 14
# Description: SNACK TRAY HAPPY FOREST  , Count: 26
# Description: SNACK TRAY PAISLEY PARK, Count: 34
# Description: SET OF 6 RIBBONS COUNTRY STYLE, Count: 27
# Description: SNACK TRAY RED VINTAGE DOILY, Count: 38
# Description: SET OF 6 RIBBONS PERFECTLY PRETTY  , Count: 45
# Description: SET OF 6 RIBBONS PARTY, Count: 16
# Description: SET 10 CARDS SNOWY ROBIN 17099, Count: 1
# Description: lost in space, Count: 1
# Description: SET 10 CARDS SWIRLY XMAS TREE 17104, Count: 1
# Description: wet?, Count: 1
# Description: lost??, Count: 1
# Description: ???, Count: 1
# Description: LETTER "U" BLING KEY RING, Count: 1
# Description: wet, Count: 1
# Description: wet boxes, Count: 1
# Description: ????damages????, Count: 1
# Description: mixed up, Count: 2
# Description: lost, Count: 1
# Description: CREAM HANGING HEART T-LIGHT HOLDER, Count: 9
# Description: PAPER CRAFT , LITTLE BIRDIE, Count: 2

# %%
# takeSample(withReplacement, num, seed): Return a random sample of the RDD (can sample with or without replacement)
# Take a random sample of 5 elements without replacement
sampled_data = rdd.takeSample(withReplacement=False, num=5, seed=42)
print("Sampled Data:")
for record in sampled_data:
    print(record)
# Out:
# Sampled Data:
# Row(InvoiceNo='575477', StockCode='84997D', Description='CHILDRENS CUTLERY POLKADOT PINK', Quantity=1, InvoiceDate=datetime.datetime(2011, 11, 9, 16, 14), UnitPrice=8.29, CustomerID=nan, Country='United Kingdom')
# Row(InvoiceNo='548191', StockCode='21430', Description='SET/3 RED GINGHAM ROSE STORAGE BOX', Quantity=1, InvoiceDate=datetime.datetime(2011, 3, 29, 15, 20), UnitPrice=7.46, CustomerID=nan, Country='United Kingdom')
# Row(InvoiceNo='558999', StockCode='84077', Description='WORLD WAR 2 GLIDERS ASSTD DESIGNS', Quantity=48, InvoiceDate=datetime.datetime(2011, 7, 5, 12, 15), UnitPrice=0.29, CustomerID=15806.0, Country='United Kingdom')
# Row(InvoiceNo='564712', StockCode='23319', Description="BOX OF 6 MINI 50'S CRACKERS", Quantity=6, InvoiceDate=datetime.datetime(2011, 8, 28, 10, 40), UnitPrice=2.49, CustomerID=15611.0, Country='United Kingdom')
# Row(InvoiceNo='574025', StockCode='22197', Description='POPCORN HOLDER', Quantity=4, InvoiceDate=datetime.datetime(2011, 11, 2, 12, 26), UnitPrice=0.85, CustomerID=12748.0, Country='United Kingdom')

# %% [markdown]
# # 5. Mid-Level: DataFrame Operations

# %%
from pyspark.sql.functions import col

# Convert Pandas DataFrame to Spark DataFrame
df_spark = spark.createDataFrame(df)

# Select specific columns and filter
filtered_df = df_spark.select("InvoiceNo", "Description", "Quantity", "UnitPrice")\
                      .filter(col("Quantity") > 0)

print("Filtered DataFrame (Quantity > 0, first 5):")
filtered_df.show(5, truncate=False)
# Out:
# Filtered DataFrame (Quantity > 0, first 5):
# +---------+-----------------------------------+--------+---------+
# |InvoiceNo|Description                        |Quantity|UnitPrice|
# +---------+-----------------------------------+--------+---------+
# |536365   |WHITE HANGING HEART T-LIGHT HOLDER |6       |2.55     |
# |536365   |WHITE METAL LANTERN                |6       |3.39     |
# |536365   |CREAM CUPID HEARTS COAT HANGER     |8       |2.75     |
# |536365   |KNITTED UNION FLAG HOT WATER BOTTLE|6       |3.39     |
# |536365   |RED WOOLLY HOTTIE WHITE HEART.     |6       |3.39     |
# +---------+-----------------------------------+--------+---------+
# only showing top 5 rows

# %%
# Show Schema of the DataFrame
df_spark.printSchema()
# Out:
# root
#  |-- InvoiceNo: string (nullable = true)
#  |-- StockCode: string (nullable = true)
#  |-- Description: string (nullable = true)
#  |-- Quantity: long (nullable = true)
#  |-- InvoiceDate: timestamp (nullable = true)
#  |-- UnitPrice: double (nullable = true)
#  |-- CustomerID: double (nullable = true)
#  |-- Country: string (nullable = true)

# %%
# Select Specific Columns
df_spark.select("Description", "Quantity").show(5, truncate=False)
# Out:
# +-----------------------------------+--------+
# |Description                        |Quantity|
# +-----------------------------------+--------+
# |WHITE HANGING HEART T-LIGHT HOLDER |6       |
# |WHITE METAL LANTERN                |6       |
# |CREAM CUPID HEARTS COAT HANGER     |8       |
# |KNITTED UNION FLAG HOT WATER BOTTLE|6       |
# |RED WOOLLY HOTTIE WHITE HEART.     |6       |
# +-----------------------------------+--------+
# only showing top 5 rows

# %%
# Filter Rows Based on a Condition
from pyspark.sql.functions import col

df_spark.filter(col("Quantity") > 5).show(5, truncate=False)
# Out:
# +---------+---------+-----------------------------------+--------+-------------------+---------+----------+--------------+
# |InvoiceNo|StockCode|Description                        |Quantity|InvoiceDate        |UnitPrice|CustomerID|Country       |
# +---------+---------+-----------------------------------+--------+-------------------+---------+----------+--------------+
# |536365   |85123A   |WHITE HANGING HEART T-LIGHT HOLDER |6       |2010-12-01 08:26:00|2.55     |17850.0   |United Kingdom|
# |536365   |71053    |WHITE METAL LANTERN                |6       |2010-12-01 08:26:00|3.39     |17850.0   |United Kingdom|
# |536365   |84406B   |CREAM CUPID HEARTS COAT HANGER     |8       |2010-12-01 08:26:00|2.75     |17850.0   |United Kingdom|
# |536365   |84029G   |KNITTED UNION FLAG HOT WATER BOTTLE|6       |2010-12-01 08:26:00|3.39     |17850.0   |United Kingdom|
# |536365   |84029E   |RED WOOLLY HOTTIE WHITE HEART.     |6       |2010-12-01 08:26:00|3.39     |17850.0   |United Kingdom|
# +---------+---------+-----------------------------------+--------+-------------------+---------+----------+--------------+
# only showing top 5 rows

# %%
# Add a New Column (e.g., Total Price)
df_spark = df_spark.withColumn("TotalPrice", col("Quantity") * col("UnitPrice"))
df_spark.show(5, truncate=False)
# Out:
# +---------+---------+-----------------------------------+--------+-------------------+---------+----------+--------------+------------------+
# |InvoiceNo|StockCode|Description                        |Quantity|InvoiceDate        |UnitPrice|CustomerID|Country       |TotalPrice        |
# +---------+---------+-----------------------------------+--------+-------------------+---------+----------+--------------+------------------+
# |536365   |85123A   |WHITE HANGING HEART T-LIGHT HOLDER |6       |2010-12-01 08:26:00|2.55     |17850.0   |United Kingdom|15.299999999999999|
# |536365   |71053    |WHITE METAL LANTERN                |6       |2010-12-01 08:26:00|3.39     |17850.0   |United Kingdom|20.34             |
# |536365   |84406B   |CREAM CUPID HEARTS COAT HANGER     |8       |2010-12-01 08:26:00|2.75     |17850.0   |United Kingdom|22.0              |
# |536365   |84029G   |KNITTED UNION FLAG HOT WATER BOTTLE|6       |2010-12-01 08:26:00|3.39     |17850.0   |United Kingdom|20.34             |
# |536365   |84029E   |RED WOOLLY HOTTIE WHITE HEART.     |6       |2010-12-01 08:26:00|3.39     |17850.0   |United Kingdom|20.34             |
# +---------+---------+-----------------------------------+--------+-------------------+---------+----------+--------------+------------------+
# only showing top 5 rows

# %%
#  Group By and Aggregate
df_spark.groupBy("Country").sum("TotalPrice").show(truncate=False)
# Out:
# +------------------+------------------+
# |Country           |sum(TotalPrice)   |
# +------------------+------------------+
# |Sweden            |36595.90999999999 |
# |Singapore         |9120.390000000001 |
# |Germany           |221698.2100000001 |
# |France            |197403.90000000026|
# |Greece            |4710.5199999999995|
# |European Community|1291.7499999999998|
# |Belgium           |40910.95999999998 |
# |Finland           |22326.74          |
# |Malta             |2505.470000000001 |
# |Unspecified       |4749.789999999998 |
# |Italy             |16890.509999999987|
# |EIRE              |263276.81999999884|
# |Lithuania         |1661.06           |
# |Norway            |35163.46000000001 |
# |Spain             |54774.5800000002  |
# |Denmark           |18768.139999999992|
# |Hong Kong         |10117.039999999997|
# |Iceland           |4310.000000000001 |
# |Israel            |7907.82           |
# |Channel Islands   |20086.289999999983|
# +------------------+------------------+
# only showing top 20 rows

# %%
# Group by and aggregate
from pyspark.sql.functions import sum, avg, count, desc

# Group by and aggregate
sales_by_country = df_spark.groupBy("Country")\
    .agg(
        sum("Quantity").alias("TotalQuantity"),
        avg("UnitPrice").alias("AvgUnitPrice"),
        count("InvoiceNo").alias("InvoiceCount")
    )\
    .orderBy(desc("TotalQuantity"))

print("Sales by Country (top 5):")
sales_by_country.show(5, truncate=False)
# Out:
# Sales by Country (top 5):
# +--------------+-------------+------------------+------------+
# |Country       |TotalQuantity|AvgUnitPrice      |InvoiceCount|
# +--------------+-------------+------------------+------------+
# |United Kingdom|4263829      |4.532422174138713 |495478      |
# |Netherlands   |200128       |2.738317165752836 |2371        |
# |EIRE          |142637       |5.9110773548073405|8196        |
# |Germany       |117448       |3.966929963138557 |9495        |
# |France        |110480       |5.028864087881326 |8557        |
# +--------------+-------------+------------------+------------+
# only showing top 5 rows

# %% [markdown]
# ##  Mid-level: SQL Operations

# %%
# Register the Spark dataframe as a temporary SQL view
df_spark.createOrReplaceTempView("sales")

# %%
# SELECT Specific Columns
spark.sql("SELECT InvoiceNo, Description, Quantity FROM sales").show(5, truncate=False)
# Out:
# +---------+-----------------------------------+--------+
# |InvoiceNo|Description                        |Quantity|
# +---------+-----------------------------------+--------+
# |536365   |WHITE HANGING HEART T-LIGHT HOLDER |6       |
# |536365   |WHITE METAL LANTERN                |6       |
# |536365   |CREAM CUPID HEARTS COAT HANGER     |8       |
# |536365   |KNITTED UNION FLAG HOT WATER BOTTLE|6       |
# |536365   |RED WOOLLY HOTTIE WHITE HEART.     |6       |
# +---------+-----------------------------------+--------+
# only showing top 5 rows

# %%
# WHERE Clause (Filtering Rows)
spark.sql("SELECT * FROM sales WHERE Quantity > 5").show(5, truncate=False)
# Out:
# +---------+---------+-----------------------------------+--------+-------------------+---------+----------+--------------+------------------+
# |InvoiceNo|StockCode|Description                        |Quantity|InvoiceDate        |UnitPrice|CustomerID|Country       |TotalPrice        |
# +---------+---------+-----------------------------------+--------+-------------------+---------+----------+--------------+------------------+
# |536365   |85123A   |WHITE HANGING HEART T-LIGHT HOLDER |6       |2010-12-01 08:26:00|2.55     |17850.0   |United Kingdom|15.299999999999999|
# |536365   |71053    |WHITE METAL LANTERN                |6       |2010-12-01 08:26:00|3.39     |17850.0   |United Kingdom|20.34             |
# |536365   |84406B   |CREAM CUPID HEARTS COAT HANGER     |8       |2010-12-01 08:26:00|2.75     |17850.0   |United Kingdom|22.0              |
# |536365   |84029G   |KNITTED UNION FLAG HOT WATER BOTTLE|6       |2010-12-01 08:26:00|3.39     |17850.0   |United Kingdom|20.34             |
# |536365   |84029E   |RED WOOLLY HOTTIE WHITE HEART.     |6       |2010-12-01 08:26:00|3.39     |17850.0   |United Kingdom|20.34             |
# +---------+---------+-----------------------------------+--------+-------------------+---------+----------+--------------+------------------+
# only showing top 5 rows

# %%
# ORDER BY (Sorting Results)
spark.sql("SELECT Description, Quantity FROM sales ORDER BY Quantity DESC").show(5, truncate=False)
# Out:
# +---------------------------------+--------+
# |Description                      |Quantity|
# +---------------------------------+--------+
# |PAPER CRAFT , LITTLE BIRDIE      |80995   |
# |MEDIUM CERAMIC TOP STORAGE JAR   |74215   |
# |ASSTD DESIGN 3D PAPER STICKERS   |12540   |
# |NaN                              |5568    |
# |WORLD WAR 2 GLIDERS ASSTD DESIGNS|4800    |
# +---------------------------------+--------+
# only showing top 5 rows

# %%
# GROUP BY with Aggregation
spark.sql("""
SELECT Country, SUM(Quantity) AS TotalQuantity
FROM sales
GROUP BY Country
ORDER BY TotalQuantity DESC
""").show(truncate=False)
# Out:
# +---------------+-------------+
# |Country        |TotalQuantity|
# +---------------+-------------+
# |United Kingdom |4263829      |
# |Netherlands    |200128       |
# |EIRE           |142637       |
# |Germany        |117448       |
# |France         |110480       |
# |Australia      |83653        |
# |Sweden         |35637        |
# |Switzerland    |30325        |
# |Spain          |26824        |
# |Japan          |25218        |
# |Belgium        |23152        |
# |Norway         |19247        |
# |Portugal       |16180        |
# |Finland        |10666        |
# |Channel Islands|9479         |
# |Denmark        |8188         |
# |Italy          |7999         |
# |Cyprus         |6317         |
# |Singapore      |5234         |
# |Austria        |4827         |
# +---------------+-------------+
# only showing top 20 rows

# %%
# COUNT DISTINCT
spark.sql("SELECT COUNT(DISTINCT Description) AS UniqueItems FROM sales").show()
# Out:
# +-----------+
# |UniqueItems|
# +-----------+
# |       4224|
# +-----------+

# %% [markdown]
# # 6. High-Level: Machine Learning

# %%
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.classification import LogisticRegression
from pyspark.ml.evaluation import BinaryClassificationEvaluator
from pyspark.ml import Pipeline

# 1. Prepare Data (simulate a binary target)
from pyspark.sql.functions import when

# Add a label column: 1 if TotalPrice > 50, else 0
df_ml = df_spark.withColumn("TotalPrice", col("Quantity") * col("UnitPrice"))
df_ml = df_ml.withColumn("label", when(col("TotalPrice") > 50, 1).otherwise(0))

# %%
# 2. Vector Assembler
assembler = VectorAssembler(
    inputCols=["Quantity", "UnitPrice"],
    outputCol="features"
)

# %%
# 3. Split and Train Model
# Split data
train_data, test_data = df_ml.randomSplit([0.8, 0.2], seed=42)

# Logistic Regression Model
lr = LogisticRegression(featuresCol="features", labelCol="label")

# Pipeline
pipeline = Pipeline(stages=[assembler, lr])
model = pipeline.fit(train_data)

# %%
#  4. Evaluate
predictions = model.transform(test_data)
predictions.select("features", "label", "prediction").show(20)

evaluator = BinaryClassificationEvaluator()
accuracy = evaluator.evaluate(predictions)
print(f"Model Accuracy: {accuracy:.4f}")
# Out:
# +-----------+-----+----------+
# |   features|label|prediction|
# +-----------+-----+----------+
# | [6.0,3.39]|    0|       0.0|
# | [6.0,2.55]|    0|       0.0|
# | [6.0,1.85]|    0|       0.0|
# | [2.0,9.95]|    0|       0.0|
# |[32.0,1.69]|    1|       0.0|
# | [3.0,4.95]|    0|       0.0|
# |[24.0,1.65]|    0|       0.0|
# |[24.0,0.42]|    0|       0.0|
# | [3.0,18.0]|    1|       0.0|
# |[80.0,2.55]|    1|       1.0|
# | [6.0,1.85]|    0|       0.0|
# | [6.0,4.95]|    0|       0.0|
# | [6.0,1.06]|    0|       0.0|
# | [6.0,1.06]|    0|       0.0|
# | [6.0,3.39]|    0|       0.0|
# | [6.0,4.25]|    0|       0.0|
# | [6.0,2.55]|    0|       0.0|
# |[12.0,3.75]|    0|       0.0|
# | [1.0,4.95]|    0|       0.0|
# |[10.0,1.65]|    0|       0.0|
# +-----------+-----+----------+
# only showing top 20 rows
#
# Model Accuracy: 0.9257
